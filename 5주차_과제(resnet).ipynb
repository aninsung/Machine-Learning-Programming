# %% [markdown]
# <a href="https://colab.research.google.com/github/aninsung/Machine-Learning-Programming/blob/main/5%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C(resnet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📌 PPG/ECG 기반 혈압 예측 과제 정리
#
# 1. **데이터 준비**
#
#    * PPG, ECG 신호 데이터 다운로드 후 Colab에 저장
#    * 경로 수정 후 예제 코드 실행
#
# 2. **분석 및 예측**
#
#    * GPT를 활용해 데이터 분석
#    * 목표: SBP(수축기 혈압), DBP(이완기 혈압) 회귀 예측
#
# 3. **데이터 구성 (세그먼트 단위)**
#
#    * 전체 세그먼트 개수: 약 1600개
#    * 1600개 초과 세그먼트는 제외
#    * 세그먼트는 반드시 **순차적으로 분할** (랜덤 셔플 금지)
#    * **오버래핑 금지** → 데이터 누수 방지 목적
#
# 4. **교차 검증 (Cross Validation)**
#
#    * **폴드 수**: 4-fold (세그먼트 1600개 기준)
#    * 각 fold:
#
#      * **훈련 + 검증**: 300개 세그먼트
#      * **테스트**: 100개 세그먼트
#    * 총 1600개 → 400개씩 나누어 4번 반복 평가
#    * fold별 결과 → 평균 내기
#
# 5. **신호 활용 조건**
#
#    * PPG + ECG 동시 사용 가능
#    * 단, PPG 신호만으로도 잘 작동하는 경우 PPG 단독 사용 허용
#
# 6. **평가지표**
#
#    * **MAE (Mean Absolute Error)** 사용
#    * SBP, DBP 각각에 대해 MAE 계산
#    * 목표: **MAE ≤ 5** (국제 표준 허용 범위)
#
# ---
#
# 👉 핵심 요약:
#
# * PPG, ECG → SBP/DBP 회귀 예측
# * 1600 세그먼트 사용, 순차 분할, 오버래핑 금지
# * 4-fold cross validation (훈련 300 + 테스트 100)
# * 평가 지표: SBP/DBP 각각의 MAE ≤ 5

# %% [markdown]
# ---
# ---
#
# ## 🩺 **혈압 예측 과제 정리 (PulseDB 기반)**
#
# ### 📌 **1. 데이터 선택**
#
# * **PulseDB**에서 **2000세그먼트 이상**을 가진 **한 명의 환자(subject)** 선택
#
#   * 세그먼트가 많을수록(약 **250MB 이상**) 안전
#   * 단, **다른 학생과 중복 불가** → 환자 번호(`pxxxxx`)를 단톡방에 올려 공지
#   * **어제 예제 환자는 제외**
# * **혈압 범위 조건 (권장):**
#
#   * SBP (수축기 혈압): 130 ~ 140 이하
#   * DBP (이완기 혈압): 80 이상
#     → 모델 성능이 더 잘 나올 확률이 높음
#
# ---
#
# ### 📊 **2. 데이터 구성**
#
# * 전체 구간의 **SBP, DBP를 그래프로 시각화**
#
#   * **X축:** 세그먼트 번호
#   * **Y축:** SBP / DBP 값
#   * 혈압의 시간적 변동을 한눈에 볼 수 있도록
# * 전체 데이터를 **시간 순서대로 5개 구간**으로 나누기 (오버래핑 없이)
#
#   * 각 구간의 용도:
#
#     * **320 세그먼트 → 훈련(train)**
#     * **40 세그먼트 → 검증(validation)**
#     * **40 세그먼트 → 테스트(test)**
#   * 즉, 5개의 폴드(fold)를 만들어 **5-Fold Cross Validation** 수행
#
# ---
#
# ### 🧠 **3. 모델 구성**
#
# * 모델은 **두 가지 버전**으로 학습 및 평가해야 함:
#
#   1. **PPG only**
#   2. **ECG + PPG**
# * 기본 모델: **CNN**
#
#   * CNN만 사용 시 → **B 수준**
#   * CNN + 다른 모델 (예: LSTM, Transformer 등) → **A 수준**
#
# ---
#
# ### 📈 **4. 성능 평가**
#
# * 각 폴드별로 **MAE**와 **RMSE** 계산
# * 결과는 다음을 모두 포함해야 함:
#
#   * Fold 1~5별 **MAE, RMSE**
#   * 전체 평균 및 **표준편차 (Mean ± Std)**
#   * 두 모델 버전 모두에 대해 표시
#     → 즉, **ECG+PPG / PPG only 각각에 대한**
#
#     * MAE (5개 fold + 평균 ± 표준편차)
#     * RMSE (5개 fold + 평균 ± 표준편차)
#
# ---
#
# ### 📅 **5. 제출 및 평가 기준**
#
# * **제출기한:** 2025년 **11월 16일 (기말고사까지)**
# * **기본 수행 (B 수준)**
#
#   * PPG only
#   * CNN 모델
#   * 5-Fold 교차검증 및 MAE/RMSE 계산
# * **고급 수행 (A 수준)**
#
#   * ECG+PPG 결합 모델
#   * CNN + 다른 모델 구조 사용
#   * 추가 아이디어나 성능 개선 기법 포함 시 가산점
#
# ---
#
# ### 🧾 **최종 제출 항목**
#
# 1. 환자 번호 (`pxxxxx`)
# 2. 전체 혈압 변화 그래프 (SBP/DBP)
# 3. 모델 종류별 결과표
#
#    * ECG+PPG, PPG only
#    * Fold별 MAE, RMSE
#    * 평균 및 표준편차
# 4. 모델 설명 (간단한 구조 요약 가능)

# %% [markdown]
# ## 데이터 분석
# * 이 `.mat` 파일은 **MATLAB v7.3 형식(HDF5 기반)** 입니다.
#
# * 최상위 키:
#
#   * `#refs#`
#   * `Subj_Wins`
#
# * `Subj_Wins` 안에는 여러 변수들이 들어 있습니다. 주요 항목:
#
#   * **신호 데이터**:
#
#     * `ECG_Raw`, `PPG_Raw`, `ABP_Raw`
#     * 주파수 관련: `ECG_F`, `PPG_F`, `ABP_F`
#   * **혈압 관련 값**:
#
#     * `SegSBP` (세그먼트별 수축기 혈압)
#     * `SegDBP` (세그먼트별 이완기 혈압)
#   * **피크/특징 정보**:
#
#     * `ECG_RPeaks`, `PPG_SPeaks`, `ABP_SPeaks`
#     * `PPG_Turns`, `ABP_Turns`
#   * **메타데이터**:
#
#     * `Age`, `Gender`, `SubjectID`, `SegmentID`, `WinID`, `WinSeqID`, `CaseID`
#
# 즉 이 파일에는 **ECG, PPG, ABP 원시 신호와 주파수/피크 정보, 그리고 세그먼트별 SBP/DBP 라벨**이 모두 포함되어 있습니다.

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# ========================
# 데이터 로딩 함수
# ========================
def load_signals_from_mat(mat_path, num_samples=5):
    """
    MATLAB .mat 파일에서 PPG, ABP, ECG 신호를 로드

    Parameters:
    - mat_path: .mat 파일 경로
    - num_samples: 로드할 샘플 개수

    Returns:
    - signals: dict {'ppg': [], 'abp': [], 'ecg': [], 'sbp': [], 'dbp': []}
    """
    signals = {'ppg': [], 'abp': [], 'ecg': [], 'sbp': [], 'dbp': []}

    with h5py.File(mat_path, 'r') as f:
        # 데이터 참조 가져오기
        ppg_refs = f['Subj_Wins']['PPG_F'][0]
        abp_refs = f['Subj_Wins']['ABP_F'][0] if 'ABP_F' in f['Subj_Wins'] else None
        ecg_refs = f['Subj_Wins']['ECG_F'][0] if 'ECG_F' in f['Subj_Wins'] else None
        sbp_refs = f['Subj_Wins']['SegSBP'][0]
        dbp_refs = f['Subj_Wins']['SegDBP'][0]

        # 지정된 개수만큼 로드
        total = min(len(ppg_refs), num_samples)

        for i in range(total):
            # PPG 신호
            ppg = f[ppg_refs[i]][()].squeeze().astype(np.float32)
            signals['ppg'].append(ppg)

            # ABP 신호 (있는 경우)
            if abp_refs is not None:
                abp = f[abp_refs[i]][()].squeeze().astype(np.float32)
                signals['abp'].append(abp)

            # ECG 신호 (있는 경우)
            if ecg_refs is not None:
                ecg = f[ecg_refs[i]][()].squeeze().astype(np.float32)
                signals['ecg'].append(ecg)

            # 혈압 타겟
            sbp = float(f[sbp_refs[i]][()][0][0])
            dbp = float(f[dbp_refs[i]][()][0][0])
            signals['sbp'].append(sbp)
            signals['dbp'].append(dbp)

    return signals

# %%
# 셀 1: 기본 설정
from google.colab import drive
drive.mount('/content/drive')

import os
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, callbacks
from sklearn.metrics import mean_absolute_error

# Reproducibility (best-effort)
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# 사용자 경로 지정 (실제 .mat 경로로 수정)
mat_path = "/content/drive/MyDrive/p044036.mat"

# 이전에 만든 load_signals_from_mat 함수가 있다면 호출
signals = load_signals_from_mat(mat_path, num_samples=1600)

# 안전: 최대 1600개로 맞춤
max_segs = 1600
n_segments = min(len(signals['ppg']), max_segs)
for k in ['ppg','abp','ecg','sbp','dbp']:
    signals[k] = signals[k][:n_segments]

print(f"총 세그먼트 수: {n_segments}")
# 확인 예시
print("PPG shape (segment 0) :", np.array(signals['ppg'][0]).shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 총 세그먼트 수: 1600
# PPG shape (segment 0) : (1250,)

# %%
def preprocess_signal(signal, fs=125):
    """
    Applies bandpass filter, moving average, and normalization to a signal.
    """
    filtered_signal = bandpass_filter(signal, fs=fs)
    smoothed_signal = moving_average(filtered_signal)
    normalized_signal = normalize_signal(smoothed_signal)
    return normalized_signal

# %%
from scipy.signal import butter, filtfilt

def bandpass_filter(signal, lowcut=0.5, highcut=15, fs=125, order=5):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    filtered_signal = filtfilt(b, a, signal)
    return filtered_signal

def moving_average(signal, window_size=5):
    return np.convolve(signal, np.ones(window_size)/window_size, mode='valid')

def normalize_signal(signal):
    min_val = np.min(signal)
    max_val = np.max(signal)
    if max_val - min_val == 0: # Avoid division by zero
        return signal - min_val
    return (signal - min_val) / (max_val - min_val)

# %%
fs = 125  # 샘플링 주파수

lengths = [len(s) for s in signals['ppg']]
print("PPG length unique counts:", np.unique(lengths))

# 만약 길이가 동일하다면 아래로 진행
T = lengths[0]  # 타임스텝 수 (예: 1250)
print("타임스텝 T =", T)

# X_time: (N, T, 1) — PPG 단독. ECG 병합 사용 원하면 채널 늘리기 (-> (N, T, 2))
use_ecg = True if signals['ecg'] else False
print("ECG available:", use_ecg)

X_list = []
y_list = []
for i in range(n_segments):
    p = np.array(signals['ppg'][i], dtype=float)
    p_pre = preprocess_signal(p, fs=fs)  # bandpass + moving average + normalize
    if len(p_pre) != T:
        # 안전장치: truncate or pad with zeros (shouldn't be needed if lengths equal)
        if len(p_pre) > T:
            p_pre = p_pre[:T]
        else:
            pad = np.zeros(T - len(p_pre), dtype=float)
            p_pre = np.concatenate([p_pre, pad])

    if use_ecg:
        e = np.array(signals['ecg'][i], dtype=float)
        e_pre = preprocess_signal(e, fs=fs)
        if len(e_pre) != T:
            if len(e_pre) > T:
                e_pre = e_pre[:T]
            else:
                pad = np.zeros(T - len(e_pre), dtype=float)
                e_pre = np.concatenate([e_pre, pad])
        # 2-channel input
        stacked = np.stack([p_pre, e_pre], axis=-1)  # (T, 2)
    else:
        stacked = p_pre.reshape(-1, 1)  # (T, 1)

    X_list.append(stacked)
    y_list.append([signals['sbp'][i], signals['dbp'][i]])

X_time = np.stack(X_list, axis=0).astype(np.float32)  # (N, T, C)
y = np.array(y_list, dtype=np.float32)                # (N, 2)

print("X_time shape:", X_time.shape)
print("y shape:", y.shape)
# Out:
# PPG length unique counts: [1250]
# 타임스텝 T = 1250
# ECG available: True
# X_time shape: (1600, 1250, 2)
# y shape: (1600, 2)

# %%
# 3) ResNet1D (성능 강화)
def build_resnet1d(input_shape, num_blocks=3, filters=64):
    def res_block(x, filters):
        shortcut = x
        x = layers.Conv1D(filters, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv1D(filters, 3, padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Add()([shortcut, x])
        x = layers.Activation('relu')(x)
        return x

    inputs = layers.Input(shape=input_shape)
    x = layers.Conv1D(filters, 7, padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    for _ in range(num_blocks):
        x = res_block(x, filters)
    x = layers.GlobalAveragePooling1D()(x)
    outputs = layers.Dense(2)(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %%
# 셀 4: 4-fold 순차 분할 (block_size = 400)
total = n_segments
assert total >= 400, "세그먼트가 최소 400개 이상이어야 합니다."
block_size = 400
n_blocks = total // block_size
assert n_blocks >= 4, f"블록 수가 4 미만: {n_blocks}"

folds = []
for b in range(4):  # exactly 4 folds: blocks 0..3
    start = b * block_size
    end = start + block_size
    trval_idx = np.arange(start, start + 300)   # train+val
    test_idx = np.arange(start + 300, end)      # test (100)
    folds.append({'trainval_idx': trval_idx, 'test_idx': test_idx})
    print(f"Fold {b}: trainval {start}-{start+299} ({len(trval_idx)}), test {start+300}-{end-1} ({len(test_idx)})")
# Out:
# Fold 0: trainval 0-299 (300), test 300-399 (100)
# Fold 1: trainval 400-699 (300), test 700-799 (100)
# Fold 2: trainval 800-1099 (300), test 1100-1199 (100)
# Fold 3: trainval 1200-1499 (300), test 1500-1599 (100)

# %%
EPOCHS = 60
BATCH_SIZE = 32
patience = 8

mae_sbp_list = []
mae_dbp_list = []
hist_list = []

# 모델 선택: build_cnn_lstm / build_light_cnn_lstm / build_resnet1d
model_builder = build_resnet1d

for fi, fd in enumerate(folds):
    print("\n" + "="*40)
    print(f"Starting Fold {fi}")
    trval_idx = fd['trainval_idx']
    test_idx = fd['test_idx']

    cut = int(len(trval_idx) * 0.8)
    train_idx = trval_idx[:cut]
    val_idx = trval_idx[cut:]

    X_train, y_train = X_time[train_idx], y[train_idx]
    X_val, y_val = X_time[val_idx], y[val_idx]
    X_test, y_test = X_time[test_idx], y[test_idx]

    model = model_builder(X_time.shape[1:])

    es = callbacks.EarlyStopping(monitor='val_mae', patience=patience, restore_best_weights=True, mode='min')
    rlr = callbacks.ReduceLROnPlateau(monitor='val_mae', factor=0.5, patience=4, min_lr=1e-6, mode='min')

    hist = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[es, rlr],
        shuffle=False,
        verbose=1
    )
    hist_list.append(hist)

    y_pred = model.predict(X_test)
    mae_sbp = mean_absolute_error(y_test[:,0], y_pred[:,0])
    mae_dbp = mean_absolute_error(y_test[:,1], y_pred[:,1])
    print(f"Fold {fi} — Test MAE SBP: {mae_sbp:.3f}, DBP: {mae_dbp:.3f}")

    mae_sbp_list.append(mae_sbp)
    mae_dbp_list.append(mae_dbp)

print("\n" + "="*40)
print("Cross-fold MAE summary")
print(f"SBP MAE mean: {np.mean(mae_sbp_list):.3f} (std: {np.std(mae_sbp_list):.3f})")
print(f"DBP MAE mean: {np.mean(mae_dbp_list):.3f} (std: {np.std(mae_dbp_list):.3f})")
# Out:
# ========================================
# Starting Fold 0
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 963ms/step - loss: 8342.0293 - mae: 88.2865 - val_loss: 8716.4004 - val_mae: 90.5412 - learning_rate: 0.0010
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 673ms/step - loss: 7921.8472 - mae: 85.9348 - val_loss: 8621.2158 - val_mae: 90.0293 - learning_rate: 0.0010
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 834ms/step - loss: 7677.9165 - mae: 84.5579 - val_loss: 8504.9873 - val_mae: 89.3895 - learning_rate: 0.0010
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step - loss: 7475.6289 - mae: 83.4024 - val_loss: 8356.9443 - val_mae: 88.5592 - learning_rate: 0.0010
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 898ms/step - loss: 7286.6064 - mae: 82.3078 - val_loss: 8196.8477 - val_mae: 87.6437 - learning_rate: 0.0010
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 668ms/step - loss: 7105.6504 - mae: 81.2229 - val_loss: 8013.9014 - val_mae: 86.6003 - learning_rate: 0.0010
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 678ms/step - loss: 6924.5820 - mae: 80.1163 - val_loss: 7831.7397 - val_mae: 85.5613 - learning_rate: 0.0010
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 703ms/step - loss: 6741.2349 - mae: 78.9809 - val_loss: 7675.6514 - val_mae: 84.6506 - learning_rate: 0.0010
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 710ms/step - loss: 6557.2261 - mae: 77.8260 - val_loss: 7494.6147 - val_mae: 83.5840 - learning_rate: 0.0010
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 887ms/step - loss: 6370.6738 - mae: 76.6402 - val_loss: 7279.1021 - val_mae: 82.2953 - learning_rate: 0.0010
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - loss: 6181.9336 - mae: 75.4238 - val_loss: 7041.0425 - val_mae: 80.8676 - learning_rate: 0.0010
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 846ms/step - loss: 5990.3848 - mae: 74.1756 - val_loss: 6758.4370 - val_mae: 79.1411 - learning_rate: 0.0010
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 662ms/step - loss: 5795.6577 - mae: 72.8926 - val_loss: 6434.5317 - val_mae: 77.1304 - learning_rate: 0.0010
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 881ms/step - loss: 5598.2119 - mae: 71.5649 - val_loss: 6083.0825 - val_mae: 74.8891 - learning_rate: 0.0010
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 670ms/step - loss: 5398.4043 - mae: 70.1866 - val_loss: 5734.0200 - val_mae: 72.5835 - learning_rate: 0.0010
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 795ms/step - loss: 5196.4307 - mae: 68.7604 - val_loss: 5374.2803 - val_mae: 70.1130 - learning_rate: 0.0010
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 693ms/step - loss: 4991.2803 - mae: 67.2746 - val_loss: 4999.9785 - val_mae: 67.4338 - learning_rate: 0.0010
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - loss: 4785.4722 - mae: 65.7462 - val_loss: 4655.2178 - val_mae: 64.8574 - learning_rate: 0.0010
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 655ms/step - loss: 4579.1953 - mae: 64.1810 - val_loss: 4307.8008 - val_mae: 62.1329 - learning_rate: 0.0010
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 659ms/step - loss: 4373.3359 - mae: 62.5822 - val_loss: 3990.1172 - val_mae: 59.5479 - learning_rate: 0.0010
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 817ms/step - loss: 4168.7759 - mae: 60.9540 - val_loss: 3679.6438 - val_mae: 56.9215 - learning_rate: 0.0010
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 3966.0176 - mae: 59.2979 - val_loss: 3432.5127 - val_mae: 54.7461 - learning_rate: 0.0010
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 883ms/step - loss: 3765.4731 - mae: 57.6166 - val_loss: 3182.4558 - val_mae: 52.4581 - learning_rate: 0.0010
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 673ms/step - loss: 3566.8291 - mae: 55.9077 - val_loss: 2979.2009 - val_mae: 50.5267 - learning_rate: 0.0010
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 885ms/step - loss: 3363.6335 - mae: 54.1143 - val_loss: 2763.1001 - val_mae: 48.4153 - learning_rate: 0.0010
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 733ms/step - loss: 3164.8767 - mae: 52.3055 - val_loss: 2548.6306 - val_mae: 46.2300 - learning_rate: 0.0010
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 642ms/step - loss: 2970.2004 - mae: 50.4745 - val_loss: 2253.2378 - val_mae: 43.0262 - learning_rate: 0.0010
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 910ms/step - loss: 2779.4729 - mae: 48.6056 - val_loss: 2025.6281 - val_mae: 40.3755 - learning_rate: 0.0010
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 637ms/step - loss: 2594.3142 - mae: 46.7181 - val_loss: 1818.1790 - val_mae: 37.8117 - learning_rate: 0.0010
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 711ms/step - loss: 2413.6641 - mae: 44.8186 - val_loss: 1622.8458 - val_mae: 35.2059 - learning_rate: 0.0010
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 765ms/step - loss: 2238.6836 - mae: 42.9158 - val_loss: 1417.1813 - val_mae: 32.2826 - learning_rate: 0.0010
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - loss: 2071.6555 - mae: 41.0231 - val_loss: 1238.7352 - val_mae: 29.6189 - learning_rate: 0.0010
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 1911.8931 - mae: 39.1380 - val_loss: 1086.4425 - val_mae: 27.1646 - learning_rate: 0.0010
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 710ms/step - loss: 1759.6426 - mae: 37.2612 - val_loss: 946.1904 - val_mae: 24.7227 - learning_rate: 0.0010
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 850ms/step - loss: 1615.4727 - mae: 35.4031 - val_loss: 810.8754 - val_mae: 22.1342 - learning_rate: 0.0010
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 662ms/step - loss: 1479.4829 - mae: 33.5736 - val_loss: 687.4072 - val_mae: 19.6663 - learning_rate: 0.0010
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 1351.5695 - mae: 31.7758 - val_loss: 578.1616 - val_mae: 17.5691 - learning_rate: 0.0010
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - loss: 1231.4907 - mae: 30.0072 - val_loss: 503.4329 - val_mae: 16.5723 - learning_rate: 0.0010
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 682ms/step - loss: 1119.5099 - mae: 28.2797 - val_loss: 451.9461 - val_mae: 16.0889 - learning_rate: 0.0010
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 666ms/step - loss: 1015.6379 - mae: 26.6040 - val_loss: 391.6075 - val_mae: 15.5864 - learning_rate: 0.0010
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 689ms/step - loss: 919.2134 - mae: 24.9736 - val_loss: 343.5190 - val_mae: 15.1026 - learning_rate: 0.0010
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 890ms/step - loss: 830.5769 - mae: 23.4065 - val_loss: 291.0329 - val_mae: 14.5101 - learning_rate: 0.0010
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - loss: 748.7004 - mae: 21.8985 - val_loss: 243.5888 - val_mae: 13.8832 - learning_rate: 0.0010
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 727ms/step - loss: 674.3329 - mae: 20.4685 - val_loss: 216.5153 - val_mae: 13.3381 - learning_rate: 0.0010
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 762ms/step - loss: 606.4393 - mae: 19.1056 - val_loss: 191.9186 - val_mae: 12.8497 - learning_rate: 0.0010
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 656ms/step - loss: 544.6301 - mae: 17.8137 - val_loss: 183.8326 - val_mae: 12.4712 - learning_rate: 0.0010
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 666ms/step - loss: 488.5530 - mae: 16.6054 - val_loss: 182.6716 - val_mae: 12.1030 - learning_rate: 0.0010
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 694ms/step - loss: 438.6077 - mae: 15.5357 - val_loss: 191.9266 - val_mae: 11.7666 - learning_rate: 0.0010
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 897ms/step - loss: 395.2650 - mae: 14.6184 - val_loss: 169.5896 - val_mae: 11.2098 - learning_rate: 0.0010
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 661ms/step - loss: 357.0572 - mae: 13.8566 - val_loss: 99.5925 - val_mae: 9.8710 - learning_rate: 0.0010
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 663ms/step - loss: 316.8277 - mae: 12.9910 - val_loss: 93.8333 - val_mae: 9.1471 - learning_rate: 0.0010
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 907ms/step - loss: 281.8551 - mae: 12.1951 - val_loss: 80.7618 - val_mae: 8.8564 - learning_rate: 0.0010
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 731ms/step - loss: 252.6306 - mae: 11.5563 - val_loss: 83.9490 - val_mae: 8.6408 - learning_rate: 0.0010
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 806ms/step - loss: 227.2157 - mae: 10.9972 - val_loss: 68.4237 - val_mae: 7.9989 - learning_rate: 0.0010
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 667ms/step - loss: 203.2698 - mae: 10.4196 - val_loss: 56.2214 - val_mae: 7.2804 - learning_rate: 0.0010
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 671ms/step - loss: 181.7118 - mae: 9.8522 - val_loss: 50.9510 - val_mae: 6.9422 - learning_rate: 0.0010
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 837ms/step - loss: 163.3676 - mae: 9.3398 - val_loss: 46.9627 - val_mae: 6.5303 - learning_rate: 0.0010
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 679ms/step - loss: 147.4559 - mae: 8.8625 - val_loss: 46.5192 - val_mae: 6.3119 - learning_rate: 0.0010
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 891ms/step - loss: 132.9124 - mae: 8.3945 - val_loss: 35.6319 - val_mae: 5.6664 - learning_rate: 0.0010
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 679ms/step - loss: 119.7843 - mae: 7.9369 - val_loss: 40.1186 - val_mae: 5.6374 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step
# Fold 0 — Test MAE SBP: 12.532, DBP: 1.916
#
# ========================================
# Starting Fold 1
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 932ms/step - loss: 9102.3936 - mae: 92.5197 - val_loss: 8555.7012 - val_mae: 89.3864 - learning_rate: 0.0010
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 699ms/step - loss: 8661.0215 - mae: 90.1323 - val_loss: 8512.9736 - val_mae: 89.1732 - learning_rate: 0.0010
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 646ms/step - loss: 8412.0654 - mae: 88.7581 - val_loss: 8453.5557 - val_mae: 88.8859 - learning_rate: 0.0010
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 654ms/step - loss: 8221.3730 - mae: 87.6953 - val_loss: 8376.8965 - val_mae: 88.5017 - learning_rate: 0.0010
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 794ms/step - loss: 8053.0664 - mae: 86.7543 - val_loss: 8295.4824 - val_mae: 88.0874 - learning_rate: 0.0010
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 656ms/step - loss: 7894.9697 - mae: 85.8659 - val_loss: 8210.1572 - val_mae: 87.6428 - learning_rate: 0.0010
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 881ms/step - loss: 7739.9131 - mae: 84.9887 - val_loss: 8123.2041 - val_mae: 87.1866 - learning_rate: 0.0010
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 672ms/step - loss: 7585.7012 - mae: 84.1017 - val_loss: 8031.4106 - val_mae: 86.6987 - learning_rate: 0.0010
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 7428.9482 - mae: 83.1914 - val_loss: 7926.4707 - val_mae: 86.1353 - learning_rate: 0.0010
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 640ms/step - loss: 7270.2676 - mae: 82.2565 - val_loss: 7810.5405 - val_mae: 85.5026 - learning_rate: 0.0010
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 899ms/step - loss: 7107.3940 - mae: 81.2895 - val_loss: 7679.2095 - val_mae: 84.7720 - learning_rate: 0.0010
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 651ms/step - loss: 6938.6104 - mae: 80.2751 - val_loss: 7533.2295 - val_mae: 83.9442 - learning_rate: 0.0010
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 710ms/step - loss: 6755.7017 - mae: 79.1552 - val_loss: 7374.9771 - val_mae: 83.0386 - learning_rate: 0.0010
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 647ms/step - loss: 6572.3921 - mae: 78.0146 - val_loss: 7186.7603 - val_mae: 81.9618 - learning_rate: 0.0010
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 6390.2188 - mae: 76.8626 - val_loss: 7031.1479 - val_mae: 81.0515 - learning_rate: 0.0010
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 640ms/step - loss: 6205.0415 - mae: 75.6666 - val_loss: 6856.7686 - val_mae: 80.0134 - learning_rate: 0.0010
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 730ms/step - loss: 6013.4507 - mae: 74.3998 - val_loss: 6670.7207 - val_mae: 78.8791 - learning_rate: 0.0010
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 665ms/step - loss: 5818.6475 - mae: 73.0888 - val_loss: 6478.3984 - val_mae: 77.6804 - learning_rate: 0.0010
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 877ms/step - loss: 5620.2690 - mae: 71.7237 - val_loss: 6258.6050 - val_mae: 76.2902 - learning_rate: 0.0010
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 655ms/step - loss: 5418.9370 - mae: 70.3163 - val_loss: 5997.4980 - val_mae: 74.6139 - learning_rate: 0.0010
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 790ms/step - loss: 5216.2217 - mae: 68.8829 - val_loss: 5702.8604 - val_mae: 72.6833 - learning_rate: 0.0010
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 686ms/step - loss: 5012.6514 - mae: 67.4168 - val_loss: 5411.7354 - val_mae: 70.7130 - learning_rate: 0.0010
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 649ms/step - loss: 4807.8291 - mae: 65.9103 - val_loss: 5110.6270 - val_mae: 68.6063 - learning_rate: 0.0010
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 649ms/step - loss: 4601.6865 - mae: 64.3607 - val_loss: 4831.4795 - val_mae: 66.5954 - learning_rate: 0.0010
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 4395.0405 - mae: 62.7725 - val_loss: 4546.2188 - val_mae: 64.4976 - learning_rate: 0.0010
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 660ms/step - loss: 4188.9702 - mae: 61.1512 - val_loss: 4196.7856 - val_mae: 61.8316 - learning_rate: 0.0010
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 714ms/step - loss: 3983.5466 - mae: 59.4950 - val_loss: 3790.7322 - val_mae: 58.6223 - learning_rate: 0.0010
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 774ms/step - loss: 3775.6606 - mae: 57.7737 - val_loss: 3491.1428 - val_mae: 56.0963 - learning_rate: 0.0010
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 811ms/step - loss: 3572.7188 - mae: 56.0453 - val_loss: 3229.1626 - val_mae: 53.8071 - learning_rate: 0.0010
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 641ms/step - loss: 3373.5532 - mae: 54.3010 - val_loss: 2961.5652 - val_mae: 51.3695 - learning_rate: 0.0010
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 879ms/step - loss: 3177.6985 - mae: 52.5421 - val_loss: 2747.2812 - val_mae: 49.3131 - learning_rate: 0.0010
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 639ms/step - loss: 2985.6602 - mae: 50.7677 - val_loss: 2566.6482 - val_mae: 47.5004 - learning_rate: 0.0010
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 660ms/step - loss: 2798.0347 - mae: 48.9774 - val_loss: 2383.9126 - val_mae: 45.6390 - learning_rate: 0.0010
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 882ms/step - loss: 2615.9902 - mae: 47.1772 - val_loss: 2262.9282 - val_mae: 44.3483 - learning_rate: 0.0010
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 671ms/step - loss: 2439.6492 - mae: 45.3662 - val_loss: 2112.8328 - val_mae: 42.6837 - learning_rate: 0.0010
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 652ms/step - loss: 2269.8374 - mae: 43.5518 - val_loss: 1955.8015 - val_mae: 40.8777 - learning_rate: 0.0010
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 824ms/step - loss: 2107.1135 - mae: 41.7457 - val_loss: 1828.3513 - val_mae: 39.3355 - learning_rate: 0.0010
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 644ms/step - loss: 1951.6758 - mae: 39.9527 - val_loss: 1696.9763 - val_mae: 37.6709 - learning_rate: 0.0010
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 866ms/step - loss: 1803.5614 - mae: 38.1750 - val_loss: 1589.5338 - val_mae: 36.2456 - learning_rate: 0.0010
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 636ms/step - loss: 1662.5652 - mae: 36.4139 - val_loss: 1495.2589 - val_mae: 34.9528 - learning_rate: 0.0010
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 879ms/step - loss: 1528.5087 - mae: 34.6730 - val_loss: 1423.2668 - val_mae: 33.9189 - learning_rate: 0.0010
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 645ms/step - loss: 1401.7705 - mae: 32.9594 - val_loss: 1352.5792 - val_mae: 32.8814 - learning_rate: 0.0010
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 825ms/step - loss: 1283.2489 - mae: 31.2835 - val_loss: 1267.6794 - val_mae: 31.6259 - learning_rate: 0.0010
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 656ms/step - loss: 1172.4866 - mae: 29.6450 - val_loss: 1181.2499 - val_mae: 30.3418 - learning_rate: 0.0010
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 665ms/step - loss: 1069.3599 - mae: 28.0486 - val_loss: 1082.4752 - val_mae: 28.8322 - learning_rate: 0.0010
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 714ms/step - loss: 973.8438 - mae: 26.5019 - val_loss: 991.7168 - val_mae: 27.3694 - learning_rate: 0.0010
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 654ms/step - loss: 885.5034 - mae: 25.0057 - val_loss: 925.0085 - val_mae: 26.2684 - learning_rate: 0.0010
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 852ms/step - loss: 804.1460 - mae: 23.5642 - val_loss: 855.5192 - val_mae: 25.0849 - learning_rate: 0.0010
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 728.9619 - mae: 22.1708 - val_loss: 800.1646 - val_mae: 24.1374 - learning_rate: 0.0010
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 809ms/step - loss: 660.3177 - mae: 20.8424 - val_loss: 735.1721 - val_mae: 22.9408 - learning_rate: 0.0010
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 641ms/step - loss: 597.5865 - mae: 19.5792 - val_loss: 671.1331 - val_mae: 21.7514 - learning_rate: 0.0010
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 540.3992 - mae: 18.4225 - val_loss: 602.9250 - val_mae: 20.3859 - learning_rate: 0.0010
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 656ms/step - loss: 488.6505 - mae: 17.3878 - val_loss: 571.4278 - val_mae: 19.8048 - learning_rate: 0.0010
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 789ms/step - loss: 441.8930 - mae: 16.4458 - val_loss: 525.6942 - val_mae: 18.8808 - learning_rate: 0.0010
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 653ms/step - loss: 399.7344 - mae: 15.5738 - val_loss: 486.4589 - val_mae: 18.0815 - learning_rate: 0.0010
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 361.6288 - mae: 14.7541 - val_loss: 416.8371 - val_mae: 16.4343 - learning_rate: 0.0010
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 658ms/step - loss: 326.6447 - mae: 13.9680 - val_loss: 331.9835 - val_mae: 14.1511 - learning_rate: 0.0010
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 752ms/step - loss: 294.7053 - mae: 13.2112 - val_loss: 255.6288 - val_mae: 11.9301 - learning_rate: 0.0010
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 717ms/step - loss: 266.2800 - mae: 12.5022 - val_loss: 219.6918 - val_mae: 10.9341 - learning_rate: 0.0010
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 877ms/step - loss: 241.3535 - mae: 11.8492 - val_loss: 206.8019 - val_mae: 10.6237 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step
# Fold 1 — Test MAE SBP: 18.696, DBP: 3.473
#
# ========================================
# Starting Fold 2
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 923ms/step - loss: 7943.2886 - mae: 85.9899 - val_loss: 9103.5684 - val_mae: 91.8121 - learning_rate: 0.0010
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 649ms/step - loss: 7567.5059 - mae: 83.8054 - val_loss: 9045.5801 - val_mae: 91.4850 - learning_rate: 0.0010
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 7348.5410 - mae: 82.5052 - val_loss: 8980.8330 - val_mae: 91.1213 - learning_rate: 0.0010
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 641ms/step - loss: 7183.0503 - mae: 81.5126 - val_loss: 8895.9131 - val_mae: 90.6467 - learning_rate: 0.0010
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 763ms/step - loss: 7035.7373 - mae: 80.6219 - val_loss: 8787.9668 - val_mae: 90.0356 - learning_rate: 0.0010
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 683ms/step - loss: 6895.0864 - mae: 79.7551 - val_loss: 8661.1123 - val_mae: 89.3145 - learning_rate: 0.0010
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 878ms/step - loss: 6754.6089 - mae: 78.8822 - val_loss: 8522.8799 - val_mae: 88.5363 - learning_rate: 0.0010
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 640ms/step - loss: 6611.7437 - mae: 77.9822 - val_loss: 8405.2520 - val_mae: 87.8795 - learning_rate: 0.0010
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 709ms/step - loss: 6466.6831 - mae: 77.0626 - val_loss: 8265.2344 - val_mae: 87.0798 - learning_rate: 0.0010
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 876ms/step - loss: 6318.0093 - mae: 76.1138 - val_loss: 8103.4541 - val_mae: 86.1477 - learning_rate: 0.0010
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 637ms/step - loss: 6164.7124 - mae: 75.1318 - val_loss: 7904.0532 - val_mae: 84.9842 - learning_rate: 0.0010
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 6004.6270 - mae: 74.0943 - val_loss: 7688.4668 - val_mae: 83.7209 - learning_rate: 0.0010
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 699ms/step - loss: 5837.0210 - mae: 73.0026 - val_loss: 7467.1606 - val_mae: 82.3915 - learning_rate: 0.0010
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 678ms/step - loss: 5661.7427 - mae: 71.8411 - val_loss: 7267.4541 - val_mae: 81.1660 - learning_rate: 0.0010
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 640ms/step - loss: 5484.6362 - mae: 70.6361 - val_loss: 7071.0239 - val_mae: 79.9805 - learning_rate: 0.0010
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 887ms/step - loss: 5303.7285 - mae: 69.3874 - val_loss: 6834.6284 - val_mae: 78.5137 - learning_rate: 0.0010
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 679ms/step - loss: 5121.5088 - mae: 68.1198 - val_loss: 6609.0342 - val_mae: 77.1047 - learning_rate: 0.0010
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 643ms/step - loss: 4938.9072 - mae: 66.8259 - val_loss: 6336.5347 - val_mae: 75.3657 - learning_rate: 0.0010
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 649ms/step - loss: 4754.4932 - mae: 65.4890 - val_loss: 6066.2388 - val_mae: 73.5473 - learning_rate: 0.0010
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 724ms/step - loss: 4570.6274 - mae: 64.1188 - val_loss: 5802.6802 - val_mae: 71.7191 - learning_rate: 0.0010
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 742ms/step - loss: 4386.7632 - mae: 62.7134 - val_loss: 5560.9077 - val_mae: 70.0069 - learning_rate: 0.0010
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 894ms/step - loss: 4203.0000 - mae: 61.2710 - val_loss: 5328.4072 - val_mae: 68.3217 - learning_rate: 0.0010
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 638ms/step - loss: 4018.7974 - mae: 59.7861 - val_loss: 5075.8926 - val_mae: 66.4127 - learning_rate: 0.0010
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 727ms/step - loss: 3833.5732 - mae: 58.2422 - val_loss: 4806.2300 - val_mae: 64.3256 - learning_rate: 0.0010
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 741ms/step - loss: 3648.3984 - mae: 56.6624 - val_loss: 4594.3311 - val_mae: 62.6457 - learning_rate: 0.0010
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 658ms/step - loss: 3465.6135 - mae: 55.0698 - val_loss: 4363.2490 - val_mae: 60.7765 - learning_rate: 0.0010
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 875ms/step - loss: 3283.9253 - mae: 53.4528 - val_loss: 4131.5698 - val_mae: 58.8822 - learning_rate: 0.0010
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 657ms/step - loss: 3104.4170 - mae: 51.8162 - val_loss: 3901.4236 - val_mae: 56.9826 - learning_rate: 0.0010
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 641ms/step - loss: 2927.7156 - mae: 50.1521 - val_loss: 3668.2756 - val_mae: 55.0074 - learning_rate: 0.0010
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 2753.4033 - mae: 48.4517 - val_loss: 3462.7551 - val_mae: 53.2087 - learning_rate: 0.0010
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 646ms/step - loss: 2583.1868 - mae: 46.7310 - val_loss: 3237.8516 - val_mae: 51.1542 - learning_rate: 0.0010
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 879ms/step - loss: 2418.3984 - mae: 45.0021 - val_loss: 3012.4409 - val_mae: 49.0093 - learning_rate: 0.0010
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 652ms/step - loss: 2259.4038 - mae: 43.2723 - val_loss: 2767.0908 - val_mae: 46.5758 - learning_rate: 0.0010
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 815ms/step - loss: 2106.0925 - mae: 41.5452 - val_loss: 2516.0659 - val_mae: 43.9611 - learning_rate: 0.0010
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 640ms/step - loss: 1957.5168 - mae: 39.8064 - val_loss: 2283.8774 - val_mae: 41.4305 - learning_rate: 0.0010
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 1813.5859 - mae: 38.0547 - val_loss: 1983.8678 - val_mae: 37.9515 - learning_rate: 0.0010
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 635ms/step - loss: 1676.6864 - mae: 36.3245 - val_loss: 1641.0677 - val_mae: 33.5446 - learning_rate: 0.0010
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 734ms/step - loss: 1545.2314 - mae: 34.5963 - val_loss: 1369.3088 - val_mae: 29.6207 - learning_rate: 0.0010
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 707ms/step - loss: 1420.2792 - mae: 32.8857 - val_loss: 1136.8949 - val_mae: 25.7947 - learning_rate: 0.0010
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 634ms/step - loss: 1301.3120 - mae: 31.1836 - val_loss: 948.8668 - val_mae: 22.5059 - learning_rate: 0.0010
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 1188.6289 - mae: 29.5018 - val_loss: 782.5872 - val_mae: 20.3843 - learning_rate: 0.0010
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 660ms/step - loss: 1082.1034 - mae: 27.8450 - val_loss: 632.1357 - val_mae: 19.4573 - learning_rate: 0.0010
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 643ms/step - loss: 981.3719 - mae: 26.2089 - val_loss: 501.5724 - val_mae: 18.6944 - learning_rate: 0.0010
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 886.4312 - mae: 24.5945 - val_loss: 482.0372 - val_mae: 18.3054 - learning_rate: 0.0010
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 636ms/step - loss: 799.2904 - mae: 23.0367 - val_loss: 451.1378 - val_mae: 18.0654 - learning_rate: 0.0010
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 685ms/step - loss: 717.5411 - mae: 21.5042 - val_loss: 508.6085 - val_mae: 18.0494 - learning_rate: 0.0010
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 645ms/step - loss: 641.6799 - mae: 20.0076 - val_loss: 460.5895 - val_mae: 17.4966 - learning_rate: 0.0010
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 855ms/step - loss: 571.8533 - mae: 18.5586 - val_loss: 459.0538 - val_mae: 17.2402 - learning_rate: 0.0010
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 649ms/step - loss: 508.4044 - mae: 17.1810 - val_loss: 418.5935 - val_mae: 16.7581 - learning_rate: 0.0010
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 871ms/step - loss: 448.8425 - mae: 15.8559 - val_loss: 389.5930 - val_mae: 16.2171 - learning_rate: 0.0010
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 684ms/step - loss: 395.7878 - mae: 14.7001 - val_loss: 316.4169 - val_mae: 15.5057 - learning_rate: 0.0010
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 778ms/step - loss: 349.1131 - mae: 13.7267 - val_loss: 303.5921 - val_mae: 15.0987 - learning_rate: 0.0010
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 812ms/step - loss: 307.6641 - mae: 12.9156 - val_loss: 289.1377 - val_mae: 14.5549 - learning_rate: 0.0010
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 644ms/step - loss: 271.0850 - mae: 12.2238 - val_loss: 294.3121 - val_mae: 14.1886 - learning_rate: 0.0010
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 871ms/step - loss: 237.7423 - mae: 11.5779 - val_loss: 304.1508 - val_mae: 13.8268 - learning_rate: 0.0010
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 644ms/step - loss: 208.3889 - mae: 10.9746 - val_loss: 295.2212 - val_mae: 13.3693 - learning_rate: 0.0010
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 776ms/step - loss: 182.0771 - mae: 10.3960 - val_loss: 298.7983 - val_mae: 13.0532 - learning_rate: 0.0010
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 644ms/step - loss: 158.8147 - mae: 9.8299 - val_loss: 296.9022 - val_mae: 12.8422 - learning_rate: 0.0010
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 137.9502 - mae: 9.2771 - val_loss: 318.3575 - val_mae: 13.2211 - learning_rate: 0.0010
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 645ms/step - loss: 119.3758 - mae: 8.7346 - val_loss: 307.1628 - val_mae: 13.0720 - learning_rate: 0.0010
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a0026901c60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a0026901c60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step
# Fold 2 — Test MAE SBP: 24.971, DBP: 1.413
#
# ========================================
# Starting Fold 3
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 710ms/step - loss: 8765.5596 - mae: 89.8398 - val_loss: 8503.9717 - val_mae: 88.8847 - learning_rate: 0.0010
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 728ms/step - loss: 8379.6133 - mae: 88.0109 - val_loss: 8460.0166 - val_mae: 88.6869 - learning_rate: 0.0010
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 741ms/step - loss: 8146.7344 - mae: 86.8614 - val_loss: 8394.1943 - val_mae: 88.3785 - learning_rate: 0.0010
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 901ms/step - loss: 7959.0142 - mae: 85.8739 - val_loss: 8303.5957 - val_mae: 87.9322 - learning_rate: 0.0010
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 649ms/step - loss: 7790.6655 - mae: 84.9314 - val_loss: 8195.4531 - val_mae: 87.3576 - learning_rate: 0.0010
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 669ms/step - loss: 7631.2935 - mae: 84.0149 - val_loss: 8060.7783 - val_mae: 86.6285 - learning_rate: 0.0010
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 847ms/step - loss: 7475.9434 - mae: 83.1063 - val_loss: 7906.7061 - val_mae: 85.8077 - learning_rate: 0.0010
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 658ms/step - loss: 7318.4136 - mae: 82.1575 - val_loss: 7739.9688 - val_mae: 84.9056 - learning_rate: 0.0010
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 7157.7075 - mae: 81.1622 - val_loss: 7566.2729 - val_mae: 83.9441 - learning_rate: 0.0010
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 666ms/step - loss: 6994.2134 - mae: 80.1383 - val_loss: 7392.8062 - val_mae: 82.9427 - learning_rate: 0.0010
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 827ms/step - loss: 6826.9233 - mae: 79.0727 - val_loss: 7204.1001 - val_mae: 81.8200 - learning_rate: 0.0010
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 638ms/step - loss: 6655.6543 - mae: 77.9653 - val_loss: 6998.7358 - val_mae: 80.5563 - learning_rate: 0.0010
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 900ms/step - loss: 6479.0166 - mae: 76.8152 - val_loss: 6775.2915 - val_mae: 79.1901 - learning_rate: 0.0010
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 719ms/step - loss: 6297.3428 - mae: 75.6178 - val_loss: 6558.1543 - val_mae: 77.8572 - learning_rate: 0.0010
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 759ms/step - loss: 6109.8833 - mae: 74.3682 - val_loss: 6311.5312 - val_mae: 76.3710 - learning_rate: 0.0010
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 647ms/step - loss: 5916.9004 - mae: 73.0743 - val_loss: 6041.3569 - val_mae: 74.7089 - learning_rate: 0.0010
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 880ms/step - loss: 5720.7612 - mae: 71.7300 - val_loss: 5774.1396 - val_mae: 72.9866 - learning_rate: 0.0010
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 659ms/step - loss: 5521.5576 - mae: 70.3155 - val_loss: 5496.6230 - val_mae: 71.1596 - learning_rate: 0.0010
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 815ms/step - loss: 5319.2480 - mae: 68.8466 - val_loss: 5177.2207 - val_mae: 68.9787 - learning_rate: 0.0010
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 661ms/step - loss: 5114.9189 - mae: 67.3285 - val_loss: 4847.8530 - val_mae: 66.5981 - learning_rate: 0.0010
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 875ms/step - loss: 4908.5635 - mae: 65.7640 - val_loss: 4486.5562 - val_mae: 63.8969 - learning_rate: 0.0010
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 659ms/step - loss: 4700.2212 - mae: 64.1541 - val_loss: 4136.9819 - val_mae: 61.1598 - learning_rate: 0.0010
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 708ms/step - loss: 4489.8228 - mae: 62.4972 - val_loss: 3807.6541 - val_mae: 58.4461 - learning_rate: 0.0010
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 857ms/step - loss: 4277.6777 - mae: 60.7883 - val_loss: 3536.5405 - val_mae: 56.0648 - learning_rate: 0.0010
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 629ms/step - loss: 4068.8135 - mae: 59.0767 - val_loss: 3311.8630 - val_mae: 54.0659 - learning_rate: 0.0010
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 699ms/step - loss: 3863.5408 - mae: 57.3535 - val_loss: 3103.2537 - val_mae: 52.1205 - learning_rate: 0.0010
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 643ms/step - loss: 3661.4104 - mae: 55.6004 - val_loss: 2882.9937 - val_mae: 50.0104 - learning_rate: 0.0010
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 3462.5430 - mae: 53.8170 - val_loss: 2667.3354 - val_mae: 47.8821 - learning_rate: 0.0010
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 672ms/step - loss: 3266.5903 - mae: 51.9900 - val_loss: 2466.7515 - val_mae: 45.8411 - learning_rate: 0.0010
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 3074.5015 - mae: 50.1360 - val_loss: 2267.2834 - val_mae: 43.6957 - learning_rate: 0.0010
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 659ms/step - loss: 2887.6394 - mae: 48.2801 - val_loss: 2024.0463 - val_mae: 41.0136 - learning_rate: 0.0010
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 644ms/step - loss: 2706.1409 - mae: 46.4358 - val_loss: 1847.4222 - val_mae: 38.9650 - learning_rate: 0.0010
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 680ms/step - loss: 2532.6704 - mae: 44.6203 - val_loss: 1719.9017 - val_mae: 37.4210 - learning_rate: 0.0010
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 785ms/step - loss: 2365.9719 - mae: 42.8189 - val_loss: 1552.2316 - val_mae: 35.2597 - learning_rate: 0.0010
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 655ms/step - loss: 2206.0200 - mae: 41.0367 - val_loss: 1437.8552 - val_mae: 33.7400 - learning_rate: 0.0010
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 631ms/step - loss: 2053.1265 - mae: 39.2793 - val_loss: 1332.6249 - val_mae: 32.2510 - learning_rate: 0.0010
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 737ms/step - loss: 1907.3907 - mae: 37.5381 - val_loss: 1217.8412 - val_mae: 30.5673 - learning_rate: 0.0010
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 701ms/step - loss: 1768.8593 - mae: 35.8183 - val_loss: 1116.0524 - val_mae: 28.9947 - learning_rate: 0.0010
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 862ms/step - loss: 1636.1924 - mae: 34.0969 - val_loss: 1044.9797 - val_mae: 27.8042 - learning_rate: 0.0010
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 628ms/step - loss: 1510.5050 - mae: 32.3962 - val_loss: 935.1691 - val_mae: 25.9161 - learning_rate: 0.0010
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 654ms/step - loss: 1392.2709 - mae: 30.7597 - val_loss: 824.8297 - val_mae: 23.9279 - learning_rate: 0.0010
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 799ms/step - loss: 1280.5192 - mae: 29.1643 - val_loss: 706.7311 - val_mae: 21.6225 - learning_rate: 0.0010
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 798ms/step - loss: 1176.2823 - mae: 27.6189 - val_loss: 585.4131 - val_mae: 18.9879 - learning_rate: 0.0010
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 665ms/step - loss: 1078.6055 - mae: 26.1165 - val_loss: 454.9437 - val_mae: 15.8021 - learning_rate: 0.0010
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 878ms/step - loss: 986.6619 - mae: 24.6527 - val_loss: 344.9169 - val_mae: 13.8739 - learning_rate: 0.0010
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 644ms/step - loss: 900.0931 - mae: 23.2337 - val_loss: 239.7928 - val_mae: 12.9442 - learning_rate: 0.0010
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 633ms/step - loss: 819.0809 - mae: 21.8762 - val_loss: 170.7906 - val_mae: 12.2454 - learning_rate: 0.0010
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 852ms/step - loss: 743.8799 - mae: 20.6135 - val_loss: 137.6009 - val_mae: 11.5079 - learning_rate: 0.0010
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 629ms/step - loss: 674.8535 - mae: 19.4741 - val_loss: 135.0270 - val_mae: 10.6206 - learning_rate: 0.0010
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 611.3942 - mae: 18.4546 - val_loss: 157.0160 - val_mae: 10.0196 - learning_rate: 0.0010
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 637ms/step - loss: 553.4713 - mae: 17.5196 - val_loss: 179.7731 - val_mae: 10.5309 - learning_rate: 0.0010
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 754ms/step - loss: 500.3802 - mae: 16.6565 - val_loss: 196.7502 - val_mae: 11.3055 - learning_rate: 0.0010
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 628ms/step - loss: 451.8918 - mae: 15.8453 - val_loss: 212.0103 - val_mae: 12.1862 - learning_rate: 0.0010
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 849ms/step - loss: 407.5658 - mae: 15.0662 - val_loss: 217.6601 - val_mae: 12.7433 - learning_rate: 0.0010
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 627ms/step - loss: 370.8638 - mae: 14.3962 - val_loss: 224.0779 - val_mae: 13.0978 - learning_rate: 5.0000e-04
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 712ms/step - loss: 352.6633 - mae: 14.0857 - val_loss: 192.4071 - val_mae: 11.9296 - learning_rate: 5.0000e-04
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 723ms/step - loss: 334.1808 - mae: 13.6900 - val_loss: 169.1390 - val_mae: 11.0206 - learning_rate: 5.0000e-04
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 626ms/step - loss: 316.5882 - mae: 13.2886 - val_loss: 156.1268 - val_mae: 10.5061 - learning_rate: 5.0000e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step
# Fold 3 — Test MAE SBP: 6.458, DBP: 15.486
#
# ========================================
# Cross-fold MAE summary
# SBP MAE mean: 15.664 (std: 6.899)
# DBP MAE mean: 5.572 (std: 5.774)

# %%
# 셀 6: 학습곡선(MAE) 플롯
plt.figure(figsize=(12, 6))

for fi, hist in enumerate(hist_list):
    # train MAE
    plt.plot(hist.history['mae'], label=f'Fold {fi} Train MAE', linestyle='-')
    # val MAE
    plt.plot(hist.history['val_mae'], label=f'Fold {fi} Val MAE', linestyle='--')

plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('CNN-LSTM Fold별 학습곡선 (MAE)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44257 (\N{HANGUL SYLLABLE GOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 셀 7: SBP/DBP MAE 별도 플롯
plt.figure(figsize=(14, 6))

# SBP
plt.subplot(1, 2, 1)
for fi, hist in enumerate(hist_list):
    plt.plot(hist.history['mae'][:,0] if 'mae' in hist.history and isinstance(hist.history['mae'][0], (list, np.ndarray)) else hist.history['mae'],
             label=f'Fold {fi} Train MAE')
    plt.plot(hist.history['val_mae'][:,0] if 'val_mae' in hist.history and isinstance(hist.history['val_mae'][0], (list, np.ndarray)) else hist.history['val_mae'],
             label=f'Fold {fi} Val MAE', linestyle='--')
plt.title('SBP MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.grid(True, alpha=0.3)
plt.legend(fontsize=8)

# DBP
plt.subplot(1, 2, 2)
for fi, hist in enumerate(hist_list):
    plt.plot(hist.history['mae'][:,1] if 'mae' in hist.history and isinstance(hist.history['mae'][0], (list, np.ndarray)) else hist.history['mae'],
             label=f'Fold {fi} Train MAE')
    plt.plot(hist.history['val_mae'][:,1] if 'val_mae' in hist.history and isinstance(hist.history['val_mae'][0], (list, np.ndarray)) else hist.history['val_mae'],
             label=f'Fold {fi} Val MAE', linestyle='--')
plt.title('DBP MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.grid(True, alpha=0.3)
plt.legend(fontsize=8)

plt.tight_layout()
plt.show()
