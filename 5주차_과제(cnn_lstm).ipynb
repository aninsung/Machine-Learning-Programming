# %% [markdown]
# <a href="https://colab.research.google.com/github/aninsung/Machine-Learning-Programming/blob/main/5%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C(cnn_lstm).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📌 PPG/ECG 기반 혈압 예측 과제 정리
#
# 1. **데이터 준비**
#
#    * PPG, ECG 신호 데이터 다운로드 후 Colab에 저장
#    * 경로 수정 후 예제 코드 실행
#
# 2. **분석 및 예측**
#
#    * GPT를 활용해 데이터 분석
#    * 목표: SBP(수축기 혈압), DBP(이완기 혈압) 회귀 예측
#
# 3. **데이터 구성 (세그먼트 단위)**
#
#    * 전체 세그먼트 개수: 약 1600개
#    * 1600개 초과 세그먼트는 제외
#    * 세그먼트는 반드시 **순차적으로 분할** (랜덤 셔플 금지)
#    * **오버래핑 금지** → 데이터 누수 방지 목적
#
# 4. **교차 검증 (Cross Validation)**
#
#    * **폴드 수**: 4-fold (세그먼트 1600개 기준)
#    * 각 fold:
#
#      * **훈련 + 검증**: 300개 세그먼트
#      * **테스트**: 100개 세그먼트
#    * 총 1600개 → 400개씩 나누어 4번 반복 평가
#    * fold별 결과 → 평균 내기
#
# 5. **신호 활용 조건**
#
#    * PPG + ECG 동시 사용 가능
#    * 단, PPG 신호만으로도 잘 작동하는 경우 PPG 단독 사용 허용
#
# 6. **평가지표**
#
#    * **MAE (Mean Absolute Error)** 사용
#    * SBP, DBP 각각에 대해 MAE 계산
#    * 목표: **MAE ≤ 5** (국제 표준 허용 범위)
#
# ---
#
# 👉 핵심 요약:
#
# * PPG, ECG → SBP/DBP 회귀 예측
# * 1600 세그먼트 사용, 순차 분할, 오버래핑 금지
# * 4-fold cross validation (훈련 300 + 테스트 100)
# * 평가 지표: SBP/DBP 각각의 MAE ≤ 5

# %% [markdown]
# ## 데이터 분석
# * 이 `.mat` 파일은 **MATLAB v7.3 형식(HDF5 기반)** 입니다.
#
# * 최상위 키:
#
#   * `#refs#`
#   * `Subj_Wins`
#
# * `Subj_Wins` 안에는 여러 변수들이 들어 있습니다. 주요 항목:
#
#   * **신호 데이터**:
#
#     * `ECG_Raw`, `PPG_Raw`, `ABP_Raw`
#     * 주파수 관련: `ECG_F`, `PPG_F`, `ABP_F`
#   * **혈압 관련 값**:
#
#     * `SegSBP` (세그먼트별 수축기 혈압)
#     * `SegDBP` (세그먼트별 이완기 혈압)
#   * **피크/특징 정보**:
#
#     * `ECG_RPeaks`, `PPG_SPeaks`, `ABP_SPeaks`
#     * `PPG_Turns`, `ABP_Turns`
#   * **메타데이터**:
#
#     * `Age`, `Gender`, `SubjectID`, `SegmentID`, `WinID`, `WinSeqID`, `CaseID`
#
# 즉 이 파일에는 **ECG, PPG, ABP 원시 신호와 주파수/피크 정보, 그리고 세그먼트별 SBP/DBP 라벨**이 모두 포함되어 있습니다.

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# ========================
# 데이터 로딩 함수
# ========================
def load_signals_from_mat(mat_path, num_samples=5):
    """
    MATLAB .mat 파일에서 PPG, ABP, ECG 신호를 로드

    Parameters:
    - mat_path: .mat 파일 경로
    - num_samples: 로드할 샘플 개수

    Returns:
    - signals: dict {'ppg': [], 'abp': [], 'ecg': [], 'sbp': [], 'dbp': []}
    """
    signals = {'ppg': [], 'abp': [], 'ecg': [], 'sbp': [], 'dbp': []}

    with h5py.File(mat_path, 'r') as f:
        # 데이터 참조 가져오기
        ppg_refs = f['Subj_Wins']['PPG_F'][0]
        abp_refs = f['Subj_Wins']['ABP_F'][0] if 'ABP_F' in f['Subj_Wins'] else None
        ecg_refs = f['Subj_Wins']['ECG_F'][0] if 'ECG_F' in f['Subj_Wins'] else None
        sbp_refs = f['Subj_Wins']['SegSBP'][0]
        dbp_refs = f['Subj_Wins']['SegDBP'][0]

        # 지정된 개수만큼 로드
        total = min(len(ppg_refs), num_samples)

        for i in range(total):
            # PPG 신호
            ppg = f[ppg_refs[i]][()].squeeze().astype(np.float32)
            signals['ppg'].append(ppg)

            # ABP 신호 (있는 경우)
            if abp_refs is not None:
                abp = f[abp_refs[i]][()].squeeze().astype(np.float32)
                signals['abp'].append(abp)

            # ECG 신호 (있는 경우)
            if ecg_refs is not None:
                ecg = f[ecg_refs[i]][()].squeeze().astype(np.float32)
                signals['ecg'].append(ecg)

            # 혈압 타겟
            sbp = float(f[sbp_refs[i]][()][0][0])
            dbp = float(f[dbp_refs[i]][()][0][0])
            signals['sbp'].append(sbp)
            signals['dbp'].append(dbp)

    return signals

# %%
# 셀 1: 기본 설정
from google.colab import drive
drive.mount('/content/drive')

import os
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, callbacks
from sklearn.metrics import mean_absolute_error

# Reproducibility (best-effort)
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# 사용자 경로 지정 (실제 .mat 경로로 수정)
mat_path = "/content/drive/MyDrive/p044036.mat"

# 이전에 만든 load_signals_from_mat 함수가 있다면 호출
signals = load_signals_from_mat(mat_path, num_samples=1600)

# 안전: 최대 1600개로 맞춤
max_segs = 1600
n_segments = min(len(signals['ppg']), max_segs)
for k in ['ppg','abp','ecg','sbp','dbp']:
    signals[k] = signals[k][:n_segments]

print(f"총 세그먼트 수: {n_segments}")
# 확인 예시
print("PPG shape (segment 0) :", np.array(signals['ppg'][0]).shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 총 세그먼트 수: 1600
# PPG shape (segment 0) : (1250,)

# %%
def preprocess_signal(signal, fs=125):
    """
    Applies bandpass filter, moving average, and normalization to a signal.
    """
    filtered_signal = bandpass_filter(signal, fs=fs)
    smoothed_signal = moving_average(filtered_signal)
    normalized_signal = normalize_signal(smoothed_signal)
    return normalized_signal

# %%
from scipy.signal import butter, filtfilt

def bandpass_filter(signal, lowcut=0.5, highcut=8, fs=125, order=5):
    """
    Applies a Butterworth bandpass filter to the signal.
    """
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    filtered_signal = filtfilt(b, a, signal)
    return filtered_signal

def moving_average(signal, window_size=5):
    """
    Applies a simple moving average filter to the signal.
    """
    if window_size % 2 == 0:
        window_size += 1  # Ensure odd window size for centering
    pad_size = window_size // 2
    padded_signal = np.pad(signal, (pad_size, pad_size), mode='edge')
    smoothed_signal = np.convolve(padded_signal, np.ones(window_size)/window_size, mode='valid')
    return smoothed_signal

def normalize_signal(signal):
    """
    Normalizes the signal to have zero mean and unit standard deviation.
    """
    mean = np.mean(signal)
    std = np.std(signal)
    if std == 0:
        return signal - mean  # Avoid division by zero
    return (signal - mean) / std

# %%
fs = 125  # 샘플링 주파수

lengths = [len(s) for s in signals['ppg']]
print("PPG length unique counts:", np.unique(lengths))

# 만약 길이가 동일하다면 아래로 진행
T = lengths[0]  # 타임스텝 수 (예: 1250)
print("타임스텝 T =", T)

# X_time: (N, T, 1) — PPG 단독. ECG 병합 사용 원하면 채널 늘리기 (-> (N, T, 2))
use_ecg = True if signals['ecg'] else False
print("ECG available:", use_ecg)

X_list = []
y_list = []
for i in range(n_segments):
    p = np.array(signals['ppg'][i], dtype=float)
    p_pre = preprocess_signal(p, fs=fs)  # bandpass + moving average + normalize
    if len(p_pre) != T:
        # 안전장치: truncate or pad with zeros (shouldn't be needed if lengths equal)
        if len(p_pre) > T:
            p_pre = p_pre[:T]
        else:
            pad = np.zeros(T - len(p_pre), dtype=float)
            p_pre = np.concatenate([p_pre, pad])

    if use_ecg:
        e = np.array(signals['ecg'][i], dtype=float)
        e_pre = preprocess_signal(e, fs=fs)
        if len(e_pre) != T:
            if len(e_pre) > T:
                e_pre = e_pre[:T]
            else:
                pad = np.zeros(T - len(e_pre), dtype=float)
                e_pre = np.concatenate([e_pre, pad])
        # 2-channel input
        stacked = np.stack([p_pre, e_pre], axis=-1)  # (T, 2)
    else:
        stacked = p_pre.reshape(-1, 1)  # (T, 1)

    X_list.append(stacked)
    y_list.append([signals['sbp'][i], signals['dbp'][i]])

X_time = np.stack(X_list, axis=0).astype(np.float32)  # (N, T, C)
y = np.array(y_list, dtype=np.float32)                # (N, 2)

print("X_time shape:", X_time.shape)
print("y shape:", y.shape)
# Out:
# PPG length unique counts: [1250]
# 타임스텝 T = 1250
# ECG available: True
# X_time shape: (1600, 1250, 2)
# y shape: (1600, 2)

# %%
def build_cnn_lstm(input_shape, dropout=0.2):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv1D(64, 5, activation='relu', padding='same')(inputs)
    x = layers.MaxPooling1D(2)(x)
    x = layers.LSTM(64)(x)
    x = layers.Dropout(dropout)(x)
    outputs = layers.Dense(2)(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %%
# 셀 4: 4-fold 순차 분할 (block_size = 400)
total = n_segments
assert total >= 400, "세그먼트가 최소 400개 이상이어야 합니다."
block_size = 400
n_blocks = total // block_size
assert n_blocks >= 4, f"블록 수가 4 미만: {n_blocks}"

folds = []
for b in range(4):  # exactly 4 folds: blocks 0..3
    start = b * block_size
    end = start + block_size
    trval_idx = np.arange(start, start + 300)   # train+val
    test_idx = np.arange(start + 300, end)      # test (100)
    folds.append({'trainval_idx': trval_idx, 'test_idx': test_idx})
    print(f"Fold {b}: trainval {start}-{start+299} ({len(trval_idx)}), test {start+300}-{end-1} ({len(test_idx)})")
# Out:
# Fold 0: trainval 0-299 (300), test 300-399 (100)
# Fold 1: trainval 400-699 (300), test 700-799 (100)
# Fold 2: trainval 800-1099 (300), test 1100-1199 (100)
# Fold 3: trainval 1200-1499 (300), test 1500-1599 (100)

# %%
EPOCHS = 60
BATCH_SIZE = 32
patience = 8

mae_sbp_list = []
mae_dbp_list = []
hist_list = []

# 모델 선택: build_cnn_lstm / build_light_cnn_lstm / build_resnet1d
model_builder = build_cnn_lstm

for fi, fd in enumerate(folds):
    print("\n" + "="*40)
    print(f"Starting Fold {fi}")
    trval_idx = fd['trainval_idx']
    test_idx = fd['test_idx']

    cut = int(len(trval_idx) * 0.8)
    train_idx = trval_idx[:cut]
    val_idx = trval_idx[cut:]

    X_train, y_train = X_time[train_idx], y[train_idx]
    X_val, y_val = X_time[val_idx], y[val_idx]
    X_test, y_test = X_time[test_idx], y[test_idx]

    model = model_builder(X_time.shape[1:])

    es = callbacks.EarlyStopping(monitor='val_mae', patience=patience, restore_best_weights=True, mode='min')
    rlr = callbacks.ReduceLROnPlateau(monitor='val_mae', factor=0.5, patience=4, min_lr=1e-6, mode='min')

    hist = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[es, rlr],
        shuffle=False,
        verbose=1
    )
    hist_list.append(hist)

    y_pred = model.predict(X_test)
    mae_sbp = mean_absolute_error(y_test[:,0], y_pred[:,0])
    mae_dbp = mean_absolute_error(y_test[:,1], y_pred[:,1])
    print(f"Fold {fi} — Test MAE SBP: {mae_sbp:.3f}, DBP: {mae_dbp:.3f}")

    mae_sbp_list.append(mae_sbp)
    mae_dbp_list.append(mae_dbp)

print("\n" + "="*40)
print("Cross-fold MAE summary")
print(f"SBP MAE mean: {np.mean(mae_sbp_list):.3f} (std: {np.std(mae_sbp_list):.3f})")
print(f"DBP MAE mean: {np.mean(mae_dbp_list):.3f} (std: {np.std(mae_dbp_list):.3f})")
# Out:
# ========================================
# Starting Fold 0
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - loss: 8895.4609 - mae: 91.2359 - val_loss: 8653.7451 - val_mae: 90.2684 - learning_rate: 0.0010
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 385ms/step - loss: 8665.4590 - mae: 90.0657 - val_loss: 8213.2754 - val_mae: 87.9763 - learning_rate: 0.0010
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 635ms/step - loss: 8240.6367 - mae: 87.8325 - val_loss: 7914.6406 - val_mae: 86.3255 - learning_rate: 0.0010
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 363ms/step - loss: 7968.9048 - mae: 86.3200 - val_loss: 7674.5415 - val_mae: 84.9908 - learning_rate: 0.0010
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - loss: 7730.6167 - mae: 85.0128 - val_loss: 7462.2915 - val_mae: 83.7852 - learning_rate: 0.0010
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 550ms/step - loss: 7528.1812 - mae: 83.8657 - val_loss: 7285.7988 - val_mae: 82.7626 - learning_rate: 0.0010
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 7359.6138 - mae: 82.9079 - val_loss: 7137.7407 - val_mae: 81.8860 - learning_rate: 0.0010
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 369ms/step - loss: 7200.7412 - mae: 81.9527 - val_loss: 7006.8667 - val_mae: 81.0944 - learning_rate: 0.0010
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 557ms/step - loss: 7077.1748 - mae: 81.2246 - val_loss: 6887.4175 - val_mae: 80.3571 - learning_rate: 0.0010
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 414ms/step - loss: 6976.0322 - mae: 80.5802 - val_loss: 6772.5825 - val_mae: 79.6291 - learning_rate: 0.0010
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 366ms/step - loss: 6831.6685 - mae: 79.6729 - val_loss: 6663.0645 - val_mae: 78.9302 - learning_rate: 0.0010
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 503ms/step - loss: 6757.8931 - mae: 79.1969 - val_loss: 6561.0552 - val_mae: 78.2816 - learning_rate: 0.0010
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 6632.7412 - mae: 78.4189 - val_loss: 6463.7197 - val_mae: 77.6622 - learning_rate: 0.0010
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 437ms/step - loss: 6554.7749 - mae: 77.8982 - val_loss: 6369.6533 - val_mae: 77.0642 - learning_rate: 0.0010
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 416ms/step - loss: 6444.6279 - mae: 77.2273 - val_loss: 6277.3076 - val_mae: 76.4779 - learning_rate: 0.0010
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 531ms/step - loss: 6355.6821 - mae: 76.6724 - val_loss: 6186.6606 - val_mae: 75.8950 - learning_rate: 0.0010
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - loss: 6277.6816 - mae: 76.1560 - val_loss: 6098.1333 - val_mae: 75.3157 - learning_rate: 0.0010
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - loss: 6201.1489 - mae: 75.6344 - val_loss: 6011.8081 - val_mae: 74.7441 - learning_rate: 0.0010
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - loss: 6086.5684 - mae: 74.8894 - val_loss: 5927.1616 - val_mae: 74.1785 - learning_rate: 0.0010
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 370ms/step - loss: 5991.5918 - mae: 74.2767 - val_loss: 5844.2915 - val_mae: 73.6204 - learning_rate: 0.0010
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - loss: 5927.0659 - mae: 73.8336 - val_loss: 5763.1841 - val_mae: 73.0700 - learning_rate: 0.0010
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 622ms/step - loss: 5835.4683 - mae: 73.1949 - val_loss: 5683.5654 - val_mae: 72.5259 - learning_rate: 0.0010
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - loss: 5762.6733 - mae: 72.7092 - val_loss: 5605.2783 - val_mae: 71.9869 - learning_rate: 0.0010
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - loss: 5668.3354 - mae: 72.0572 - val_loss: 5528.2759 - val_mae: 71.4531 - learning_rate: 0.0010
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 533ms/step - loss: 5599.5176 - mae: 71.5506 - val_loss: 5452.5127 - val_mae: 70.9241 - learning_rate: 0.0010
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 440ms/step - loss: 5531.2207 - mae: 71.1165 - val_loss: 5377.8853 - val_mae: 70.3993 - learning_rate: 0.0010
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - loss: 5466.1968 - mae: 70.6404 - val_loss: 5304.4819 - val_mae: 69.8794 - learning_rate: 0.0010
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 386ms/step - loss: 5414.4077 - mae: 70.2918 - val_loss: 5232.3779 - val_mae: 69.3651 - learning_rate: 0.0010
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 607ms/step - loss: 5307.2227 - mae: 69.5120 - val_loss: 5161.2959 - val_mae: 68.8546 - learning_rate: 0.0010
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 5229.5962 - mae: 68.9756 - val_loss: 5091.1704 - val_mae: 68.3474 - learning_rate: 0.0010
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - loss: 5162.9854 - mae: 68.5101 - val_loss: 5022.0000 - val_mae: 67.8436 - learning_rate: 0.0010
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 5121.1636 - mae: 68.1476 - val_loss: 4953.7607 - val_mae: 67.3431 - learning_rate: 0.0010
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 679ms/step - loss: 5018.0425 - mae: 67.4273 - val_loss: 4886.3843 - val_mae: 66.8455 - learning_rate: 0.0010
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - loss: 4975.4736 - mae: 67.1182 - val_loss: 4819.9248 - val_mae: 66.3513 - learning_rate: 0.0010
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 376ms/step - loss: 4865.1523 - mae: 66.3253 - val_loss: 4754.2388 - val_mae: 65.8594 - learning_rate: 0.0010
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 504ms/step - loss: 4829.5137 - mae: 66.0122 - val_loss: 4689.4331 - val_mae: 65.3707 - learning_rate: 0.0010
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 399ms/step - loss: 4717.6470 - mae: 65.1908 - val_loss: 4625.3926 - val_mae: 64.8844 - learning_rate: 0.0010
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 401ms/step - loss: 4676.3052 - mae: 64.8741 - val_loss: 4562.2178 - val_mae: 64.4013 - learning_rate: 0.0010
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 599ms/step - loss: 4639.9077 - mae: 64.5821 - val_loss: 4499.9580 - val_mae: 63.9219 - learning_rate: 0.0010
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 389ms/step - loss: 4593.8696 - mae: 64.2370 - val_loss: 4438.5864 - val_mae: 63.4459 - learning_rate: 0.0010
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - loss: 4512.6123 - mae: 63.6127 - val_loss: 4378.0723 - val_mae: 62.9732 - learning_rate: 0.0010
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 576ms/step - loss: 4446.2661 - mae: 63.0796 - val_loss: 4318.3374 - val_mae: 62.5034 - learning_rate: 0.0010
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 423ms/step - loss: 4387.9590 - mae: 62.6478 - val_loss: 4259.3506 - val_mae: 62.0362 - learning_rate: 0.0010
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 367ms/step - loss: 4378.0503 - mae: 62.5258 - val_loss: 4201.1768 - val_mae: 61.5722 - learning_rate: 0.0010
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 569ms/step - loss: 4281.0356 - mae: 61.7674 - val_loss: 4143.7114 - val_mae: 61.1107 - learning_rate: 0.0010
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 394ms/step - loss: 4210.0283 - mae: 61.2341 - val_loss: 4086.8433 - val_mae: 60.6507 - learning_rate: 0.0010
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - loss: 4150.7627 - mae: 60.7337 - val_loss: 4030.6746 - val_mae: 60.1933 - learning_rate: 0.0010
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 446ms/step - loss: 4101.6021 - mae: 60.3489 - val_loss: 3975.1875 - val_mae: 59.7382 - learning_rate: 0.0010
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - loss: 4068.9685 - mae: 60.0288 - val_loss: 3920.4495 - val_mae: 59.2861 - learning_rate: 0.0010
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - loss: 3987.7979 - mae: 59.4006 - val_loss: 3866.4104 - val_mae: 58.8366 - learning_rate: 0.0010
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 3945.0884 - mae: 59.0330 - val_loss: 3813.0459 - val_mae: 58.3897 - learning_rate: 0.0010
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 528ms/step - loss: 3917.0825 - mae: 58.7918 - val_loss: 3760.3604 - val_mae: 57.9453 - learning_rate: 0.0010
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 434ms/step - loss: 3859.2063 - mae: 58.2861 - val_loss: 3708.3369 - val_mae: 57.5035 - learning_rate: 0.0010
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - loss: 3770.2559 - mae: 57.6009 - val_loss: 3656.8787 - val_mae: 57.0634 - learning_rate: 0.0010
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 3771.6060 - mae: 57.5200 - val_loss: 3606.1196 - val_mae: 56.6262 - learning_rate: 0.0010
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 620ms/step - loss: 3731.8408 - mae: 57.2175 - val_loss: 3556.0427 - val_mae: 56.1917 - learning_rate: 0.0010
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - loss: 3625.8750 - mae: 56.3183 - val_loss: 3506.5261 - val_mae: 55.7592 - learning_rate: 0.0010
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - loss: 3596.9143 - mae: 56.1003 - val_loss: 3457.6333 - val_mae: 55.3290 - learning_rate: 0.0010
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 556ms/step - loss: 3534.2224 - mae: 55.5236 - val_loss: 3409.3286 - val_mae: 54.9010 - learning_rate: 0.0010
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 373ms/step - loss: 3501.0408 - mae: 55.1988 - val_loss: 3361.6240 - val_mae: 54.4754 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step
# Fold 0 — Test MAE SBP: 78.364, DBP: 35.792
#
# ========================================
# Starting Fold 1
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 468ms/step - loss: 9181.5430 - mae: 92.5487 - val_loss: 8441.6572 - val_mae: 88.7443 - learning_rate: 0.0010
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 575ms/step - loss: 8985.4316 - mae: 91.5102 - val_loss: 8031.3018 - val_mae: 86.5095 - learning_rate: 0.0010
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - loss: 8544.8643 - mae: 89.1840 - val_loss: 7688.0410 - val_mae: 84.6091 - learning_rate: 0.0010
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - loss: 8218.7178 - mae: 87.4560 - val_loss: 7423.9575 - val_mae: 83.1034 - learning_rate: 0.0010
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - loss: 7941.6216 - mae: 85.8981 - val_loss: 7184.2314 - val_mae: 81.7003 - learning_rate: 0.0010
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 632ms/step - loss: 7701.6289 - mae: 84.5408 - val_loss: 6989.8203 - val_mae: 80.5386 - learning_rate: 0.0010
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 392ms/step - loss: 7511.8428 - mae: 83.4558 - val_loss: 6834.8740 - val_mae: 79.5931 - learning_rate: 0.0010
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 388ms/step - loss: 7353.8496 - mae: 82.5333 - val_loss: 6705.8228 - val_mae: 78.7902 - learning_rate: 0.0010
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - loss: 7230.4316 - mae: 81.7829 - val_loss: 6591.6768 - val_mae: 78.0694 - learning_rate: 0.0010
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 473ms/step - loss: 7118.0034 - mae: 81.0945 - val_loss: 6486.3574 - val_mae: 77.3983 - learning_rate: 0.0010
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - loss: 7008.7935 - mae: 80.4435 - val_loss: 6385.7651 - val_mae: 76.7580 - learning_rate: 0.0010
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - loss: 6903.9736 - mae: 79.7955 - val_loss: 6287.5435 - val_mae: 76.1292 - learning_rate: 0.0010
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 533ms/step - loss: 6802.6045 - mae: 79.1725 - val_loss: 6192.8696 - val_mae: 75.5109 - learning_rate: 0.0010
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 470ms/step - loss: 6715.4180 - mae: 78.6008 - val_loss: 6101.5259 - val_mae: 74.9068 - learning_rate: 0.0010
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 377ms/step - loss: 6594.7461 - mae: 77.8427 - val_loss: 6012.7939 - val_mae: 74.3146 - learning_rate: 0.0010
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - loss: 6509.3384 - mae: 77.3112 - val_loss: 5926.3403 - val_mae: 73.7329 - learning_rate: 0.0010
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 507ms/step - loss: 6450.6113 - mae: 76.9111 - val_loss: 5842.2188 - val_mae: 73.1625 - learning_rate: 0.0010
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 6348.7280 - mae: 76.2615 - val_loss: 5760.0845 - val_mae: 72.6013 - learning_rate: 0.0010
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - loss: 6269.5771 - mae: 75.7356 - val_loss: 5679.4995 - val_mae: 72.0467 - learning_rate: 0.0010
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 487ms/step - loss: 6184.1357 - mae: 75.1577 - val_loss: 5600.5449 - val_mae: 71.4992 - learning_rate: 0.0010
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 516ms/step - loss: 6101.6582 - mae: 74.6356 - val_loss: 5522.9980 - val_mae: 70.9576 - learning_rate: 0.0010
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - loss: 6021.0791 - mae: 74.0650 - val_loss: 5446.7720 - val_mae: 70.4214 - learning_rate: 0.0010
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - loss: 5920.7886 - mae: 73.4218 - val_loss: 5371.7095 - val_mae: 69.8895 - learning_rate: 0.0010
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 632ms/step - loss: 5835.4316 - mae: 72.8427 - val_loss: 5297.7969 - val_mae: 69.3620 - learning_rate: 0.0010
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - loss: 5783.1978 - mae: 72.4572 - val_loss: 5225.0601 - val_mae: 68.8392 - learning_rate: 0.0010
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - loss: 5698.4531 - mae: 71.8831 - val_loss: 5153.4282 - val_mae: 68.3206 - learning_rate: 0.0010
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - loss: 5621.8442 - mae: 71.3664 - val_loss: 5082.8491 - val_mae: 67.8060 - learning_rate: 0.0010
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 447ms/step - loss: 5538.8618 - mae: 70.7886 - val_loss: 5013.1807 - val_mae: 67.2944 - learning_rate: 0.0010
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - loss: 5504.5371 - mae: 70.5309 - val_loss: 4944.6948 - val_mae: 66.7877 - learning_rate: 0.0010
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - loss: 5395.9736 - mae: 69.7762 - val_loss: 4877.1201 - val_mae: 66.2843 - learning_rate: 0.0010
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 563ms/step - loss: 5323.1621 - mae: 69.2573 - val_loss: 4810.5190 - val_mae: 65.7847 - learning_rate: 0.0010
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - loss: 5285.6553 - mae: 68.9733 - val_loss: 4744.9282 - val_mae: 65.2892 - learning_rate: 0.0010
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - loss: 5192.7344 - mae: 68.3087 - val_loss: 4680.2002 - val_mae: 64.7966 - learning_rate: 0.0010
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 441ms/step - loss: 5122.5073 - mae: 67.7860 - val_loss: 4616.3188 - val_mae: 64.3072 - learning_rate: 0.0010
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 401ms/step - loss: 5087.1152 - mae: 67.5413 - val_loss: 4553.4385 - val_mae: 63.8220 - learning_rate: 0.0010
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 395ms/step - loss: 5002.4746 - mae: 66.9022 - val_loss: 4491.3804 - val_mae: 63.3397 - learning_rate: 0.0010
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - loss: 4931.2515 - mae: 66.3885 - val_loss: 4430.1030 - val_mae: 62.8601 - learning_rate: 0.0010
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 676ms/step - loss: 4865.3330 - mae: 65.9048 - val_loss: 4369.4771 - val_mae: 62.3822 - learning_rate: 0.0010
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - loss: 4783.0581 - mae: 65.2722 - val_loss: 4309.5933 - val_mae: 61.9069 - learning_rate: 0.0010
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - loss: 4713.3472 - mae: 64.7484 - val_loss: 4250.3999 - val_mae: 61.4339 - learning_rate: 0.0010
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 569ms/step - loss: 4709.1221 - mae: 64.7089 - val_loss: 4192.0972 - val_mae: 60.9645 - learning_rate: 0.0010
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 473ms/step - loss: 4597.4907 - mae: 63.8503 - val_loss: 4134.5068 - val_mae: 60.4977 - learning_rate: 0.0010
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 425ms/step - loss: 4548.3960 - mae: 63.5001 - val_loss: 4077.6980 - val_mae: 60.0338 - learning_rate: 0.0010
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 391ms/step - loss: 4492.5479 - mae: 63.0557 - val_loss: 4021.6392 - val_mae: 59.5727 - learning_rate: 0.0010
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 593ms/step - loss: 4453.2119 - mae: 62.7500 - val_loss: 3966.3662 - val_mae: 59.1148 - learning_rate: 0.0010
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 381ms/step - loss: 4378.8047 - mae: 62.1245 - val_loss: 3911.7844 - val_mae: 58.6594 - learning_rate: 0.0010
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 394ms/step - loss: 4307.3047 - mae: 61.5852 - val_loss: 3857.7800 - val_mae: 58.2058 - learning_rate: 0.0010
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 501ms/step - loss: 4292.0986 - mae: 61.4597 - val_loss: 3804.5142 - val_mae: 57.7552 - learning_rate: 0.0010
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - loss: 4201.8516 - mae: 60.7323 - val_loss: 3751.9407 - val_mae: 57.3073 - learning_rate: 0.0010
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 602ms/step - loss: 4160.8232 - mae: 60.3748 - val_loss: 3700.0151 - val_mae: 56.8617 - learning_rate: 0.0010
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4106.2808 - mae: 59.9455 - val_loss: 3648.7412 - val_mae: 56.4187 - learning_rate: 0.0010
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - loss: 4104.3491 - mae: 59.9285 - val_loss: 3598.1926 - val_mae: 55.9787 - learning_rate: 0.0010
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - loss: 3979.4343 - mae: 58.9170 - val_loss: 3548.1882 - val_mae: 55.5404 - learning_rate: 0.0010
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 604ms/step - loss: 3938.8396 - mae: 58.5680 - val_loss: 3498.7817 - val_mae: 55.1043 - learning_rate: 0.0010
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - loss: 3888.3010 - mae: 58.1274 - val_loss: 3449.9797 - val_mae: 54.6706 - learning_rate: 0.0010
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 389ms/step - loss: 3813.9890 - mae: 57.5216 - val_loss: 3401.7568 - val_mae: 54.2390 - learning_rate: 0.0010
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 566ms/step - loss: 3804.5933 - mae: 57.4055 - val_loss: 3354.2061 - val_mae: 53.8102 - learning_rate: 0.0010
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 448ms/step - loss: 3726.9224 - mae: 56.7833 - val_loss: 3307.2297 - val_mae: 53.3837 - learning_rate: 0.0010
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 404ms/step - loss: 3684.6882 - mae: 56.4314 - val_loss: 3260.8438 - val_mae: 52.9595 - learning_rate: 0.0010
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 395ms/step - loss: 3629.8286 - mae: 55.9160 - val_loss: 3215.0229 - val_mae: 52.5374 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# Fold 1 — Test MAE SBP: 72.945, DBP: 28.990
#
# ========================================
# Starting Fold 2
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 511ms/step - loss: 7975.3452 - mae: 86.1803 - val_loss: 8994.0186 - val_mae: 91.4122 - learning_rate: 0.0010
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 402ms/step - loss: 7777.5625 - mae: 85.2351 - val_loss: 8676.4072 - val_mae: 89.9620 - learning_rate: 0.0010
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - loss: 7502.1699 - mae: 83.8657 - val_loss: 8418.9541 - val_mae: 88.7008 - learning_rate: 0.0010
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 521ms/step - loss: 7261.7607 - mae: 82.5791 - val_loss: 8173.0317 - val_mae: 87.4548 - learning_rate: 0.0010
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 394ms/step - loss: 7033.3174 - mae: 81.3303 - val_loss: 7956.1353 - val_mae: 86.3265 - learning_rate: 0.0010
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 427ms/step - loss: 6842.0967 - mae: 80.2739 - val_loss: 7779.0688 - val_mae: 85.3580 - learning_rate: 0.0010
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 482ms/step - loss: 6679.1230 - mae: 79.2713 - val_loss: 7634.3647 - val_mae: 84.5314 - learning_rate: 0.0010
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 555ms/step - loss: 6552.0498 - mae: 78.4910 - val_loss: 7508.4780 - val_mae: 83.7913 - learning_rate: 0.0010
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 421ms/step - loss: 6445.5439 - mae: 77.8190 - val_loss: 7393.4053 - val_mae: 83.1026 - learning_rate: 0.0010
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 400ms/step - loss: 6329.1748 - mae: 77.0747 - val_loss: 7285.0854 - val_mae: 82.4483 - learning_rate: 0.0010
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 644ms/step - loss: 6245.9702 - mae: 76.5159 - val_loss: 7181.7217 - val_mae: 81.8199 - learning_rate: 0.0010
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 395ms/step - loss: 6156.1899 - mae: 75.9139 - val_loss: 7082.3408 - val_mae: 81.2118 - learning_rate: 0.0010
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - loss: 6050.2407 - mae: 75.2388 - val_loss: 6985.9766 - val_mae: 80.6181 - learning_rate: 0.0010
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 389ms/step - loss: 5961.0083 - mae: 74.6244 - val_loss: 6892.2749 - val_mae: 80.0369 - learning_rate: 0.0010
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 422ms/step - loss: 5870.9844 - mae: 74.0309 - val_loss: 6800.6714 - val_mae: 79.4648 - learning_rate: 0.0010
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 387ms/step - loss: 5779.4873 - mae: 73.4089 - val_loss: 6711.1387 - val_mae: 78.9019 - learning_rate: 0.0010
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 513ms/step - loss: 5702.1787 - mae: 72.8976 - val_loss: 6623.3667 - val_mae: 78.3462 - learning_rate: 0.0010
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 487ms/step - loss: 5627.8037 - mae: 72.3713 - val_loss: 6537.2905 - val_mae: 77.7978 - learning_rate: 0.0010
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 386ms/step - loss: 5546.1704 - mae: 71.8137 - val_loss: 6452.5239 - val_mae: 77.2542 - learning_rate: 0.0010
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 403ms/step - loss: 5463.3364 - mae: 71.2320 - val_loss: 6369.2036 - val_mae: 76.7169 - learning_rate: 0.0010
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 492ms/step - loss: 5394.9980 - mae: 70.7576 - val_loss: 6287.1387 - val_mae: 76.1852 - learning_rate: 0.0010
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 500ms/step - loss: 5305.7578 - mae: 70.1499 - val_loss: 6205.8262 - val_mae: 75.6573 - learning_rate: 0.0010
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 397ms/step - loss: 5261.3643 - mae: 69.8095 - val_loss: 6124.7598 - val_mae: 75.1293 - learning_rate: 0.0010
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - loss: 5179.6357 - mae: 69.2310 - val_loss: 6044.3564 - val_mae: 74.6003 - learning_rate: 0.0010
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 543ms/step - loss: 5080.1372 - mae: 68.5425 - val_loss: 5964.8896 - val_mae: 74.0711 - learning_rate: 0.0010
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 400ms/step - loss: 5042.8984 - mae: 68.2422 - val_loss: 5886.7783 - val_mae: 73.5460 - learning_rate: 0.0010
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - loss: 4963.1895 - mae: 67.6839 - val_loss: 5810.1729 - val_mae: 73.0271 - learning_rate: 0.0010
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 655ms/step - loss: 4894.6948 - mae: 67.1475 - val_loss: 5734.7739 - val_mae: 72.5127 - learning_rate: 0.0010
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 408ms/step - loss: 4816.0386 - mae: 66.5797 - val_loss: 5660.3574 - val_mae: 72.0015 - learning_rate: 0.0010
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 380ms/step - loss: 4728.3604 - mae: 65.9309 - val_loss: 5586.8589 - val_mae: 71.4933 - learning_rate: 0.0010
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - loss: 4677.8564 - mae: 65.5535 - val_loss: 5514.3057 - val_mae: 70.9882 - learning_rate: 0.0010
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 387ms/step - loss: 4617.8662 - mae: 65.0928 - val_loss: 5442.7793 - val_mae: 70.4869 - learning_rate: 0.0010
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 386ms/step - loss: 4552.3887 - mae: 64.6122 - val_loss: 5372.2925 - val_mae: 69.9895 - learning_rate: 0.0010
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 481ms/step - loss: 4488.8638 - mae: 64.0946 - val_loss: 5302.8032 - val_mae: 69.4960 - learning_rate: 0.0010
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 529ms/step - loss: 4434.7925 - mae: 63.6718 - val_loss: 5234.2808 - val_mae: 69.0060 - learning_rate: 0.0010
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - loss: 4365.2090 - mae: 63.1342 - val_loss: 5166.6846 - val_mae: 68.5194 - learning_rate: 0.0010
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 389ms/step - loss: 4302.8726 - mae: 62.6264 - val_loss: 5100.0298 - val_mae: 68.0365 - learning_rate: 0.0010
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - loss: 4237.8418 - mae: 62.1198 - val_loss: 5034.1387 - val_mae: 67.5560 - learning_rate: 0.0010
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 507ms/step - loss: 4186.4883 - mae: 61.7055 - val_loss: 4969.0562 - val_mae: 67.0783 - learning_rate: 0.0010
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 402ms/step - loss: 4136.1108 - mae: 61.3221 - val_loss: 4904.7915 - val_mae: 66.6033 - learning_rate: 0.0010
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - loss: 4066.0342 - mae: 60.7450 - val_loss: 4841.3271 - val_mae: 66.1313 - learning_rate: 0.0010
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 526ms/step - loss: 3989.6511 - mae: 60.1203 - val_loss: 4778.5850 - val_mae: 65.6615 - learning_rate: 0.0010
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 403ms/step - loss: 3943.3220 - mae: 59.7384 - val_loss: 4716.5908 - val_mae: 65.1942 - learning_rate: 0.0010
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 389ms/step - loss: 3876.6396 - mae: 59.1858 - val_loss: 4655.3687 - val_mae: 64.7297 - learning_rate: 0.0010
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - loss: 3830.0684 - mae: 58.7951 - val_loss: 4594.8618 - val_mae: 64.2675 - learning_rate: 0.0010
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 610ms/step - loss: 3780.9893 - mae: 58.3816 - val_loss: 4535.0552 - val_mae: 63.8077 - learning_rate: 0.0010
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 391ms/step - loss: 3712.6904 - mae: 57.7999 - val_loss: 4476.0269 - val_mae: 63.3510 - learning_rate: 0.0010
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 383ms/step - loss: 3647.9854 - mae: 57.2626 - val_loss: 4417.6885 - val_mae: 62.8965 - learning_rate: 0.0010
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 525ms/step - loss: 3605.5740 - mae: 56.8958 - val_loss: 4360.1084 - val_mae: 62.4449 - learning_rate: 0.0010
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 384ms/step - loss: 3587.3184 - mae: 56.6966 - val_loss: 4303.3364 - val_mae: 61.9967 - learning_rate: 0.0010
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 380ms/step - loss: 3531.3228 - mae: 56.2252 - val_loss: 4247.2568 - val_mae: 61.5510 - learning_rate: 0.0010
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 655ms/step - loss: 3494.0869 - mae: 55.9056 - val_loss: 4191.9019 - val_mae: 61.1081 - learning_rate: 0.0010
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 389ms/step - loss: 3419.2683 - mae: 55.2235 - val_loss: 4137.1636 - val_mae: 60.6673 - learning_rate: 0.0010
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 380ms/step - loss: 3362.2559 - mae: 54.7217 - val_loss: 4083.0000 - val_mae: 60.2284 - learning_rate: 0.0010
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 594ms/step - loss: 3301.4968 - mae: 54.1700 - val_loss: 4029.4602 - val_mae: 59.7917 - learning_rate: 0.0010
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - loss: 3253.4233 - mae: 53.7248 - val_loss: 3976.4937 - val_mae: 59.3569 - learning_rate: 0.0010
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - loss: 3230.2083 - mae: 53.5171 - val_loss: 3924.1787 - val_mae: 58.9246 - learning_rate: 0.0010
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 394ms/step - loss: 3171.1277 - mae: 52.9515 - val_loss: 3872.5354 - val_mae: 58.4951 - learning_rate: 0.0010
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 618ms/step - loss: 3112.8228 - mae: 52.4730 - val_loss: 3821.5010 - val_mae: 58.0677 - learning_rate: 0.0010
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - loss: 3065.2456 - mae: 52.0215 - val_loss: 3771.0256 - val_mae: 57.6421 - learning_rate: 0.0010
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cf885252480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cf885252480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# Fold 2 — Test MAE SBP: 79.634, DBP: 36.453
#
# ========================================
# Starting Fold 3
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 533ms/step - loss: 8905.0635 - mae: 90.6553 - val_loss: 8409.2695 - val_mae: 88.2508 - learning_rate: 0.0010
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 400ms/step - loss: 8703.2695 - mae: 89.5043 - val_loss: 8026.3813 - val_mae: 85.9767 - learning_rate: 0.0010
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - loss: 8324.6572 - mae: 87.2803 - val_loss: 7763.0796 - val_mae: 84.3745 - learning_rate: 0.0010
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - loss: 8076.0391 - mae: 85.8016 - val_loss: 7543.3916 - val_mae: 83.0578 - learning_rate: 0.0010
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 550ms/step - loss: 7848.9692 - mae: 84.4565 - val_loss: 7346.2749 - val_mae: 81.8474 - learning_rate: 0.0010
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 386ms/step - loss: 7659.5811 - mae: 83.3171 - val_loss: 7174.9731 - val_mae: 80.7740 - learning_rate: 0.0010
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - loss: 7492.9561 - mae: 82.2862 - val_loss: 7022.9717 - val_mae: 79.8246 - learning_rate: 0.0010
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 571ms/step - loss: 7334.2900 - mae: 81.3454 - val_loss: 6891.2354 - val_mae: 79.0057 - learning_rate: 0.0010
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 453ms/step - loss: 7218.6265 - mae: 80.6207 - val_loss: 6772.6729 - val_mae: 78.2637 - learning_rate: 0.0010
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 390ms/step - loss: 7081.1802 - mae: 79.7810 - val_loss: 6663.4429 - val_mae: 77.5707 - learning_rate: 0.0010
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 382ms/step - loss: 6974.7393 - mae: 79.1436 - val_loss: 6561.2417 - val_mae: 76.9135 - learning_rate: 0.0010
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 511ms/step - loss: 6868.7188 - mae: 78.4327 - val_loss: 6463.8154 - val_mae: 76.2803 - learning_rate: 0.0010
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 467ms/step - loss: 6780.9370 - mae: 77.8974 - val_loss: 6370.2280 - val_mae: 75.6667 - learning_rate: 0.0010
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 381ms/step - loss: 6686.9370 - mae: 77.2940 - val_loss: 6279.6479 - val_mae: 75.0681 - learning_rate: 0.0010
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - loss: 6589.1587 - mae: 76.6797 - val_loss: 6191.5200 - val_mae: 74.4814 - learning_rate: 0.0010
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 6494.6528 - mae: 76.0178 - val_loss: 6105.6675 - val_mae: 73.9058 - learning_rate: 0.0010
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - loss: 6414.2812 - mae: 75.5028 - val_loss: 6021.8799 - val_mae: 73.3399 - learning_rate: 0.0010
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 374ms/step - loss: 6314.6758 - mae: 74.8618 - val_loss: 5939.7925 - val_mae: 72.7816 - learning_rate: 0.0010
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 613ms/step - loss: 6250.3013 - mae: 74.4111 - val_loss: 5859.2729 - val_mae: 72.2301 - learning_rate: 0.0010
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 387ms/step - loss: 6162.6538 - mae: 73.8293 - val_loss: 5780.1875 - val_mae: 71.6846 - learning_rate: 0.0010
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 391ms/step - loss: 6088.3706 - mae: 73.3492 - val_loss: 5702.5439 - val_mae: 71.1453 - learning_rate: 0.0010
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 531ms/step - loss: 6005.1338 - mae: 72.7501 - val_loss: 5626.0625 - val_mae: 70.6104 - learning_rate: 0.0010
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - loss: 5913.5557 - mae: 72.1539 - val_loss: 5550.8706 - val_mae: 70.0809 - learning_rate: 0.0010
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 374ms/step - loss: 5843.1963 - mae: 71.6613 - val_loss: 5476.8174 - val_mae: 69.5557 - learning_rate: 0.0010
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 5764.2446 - mae: 71.1046 - val_loss: 5403.7944 - val_mae: 69.0344 - learning_rate: 0.0010
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - loss: 5688.2983 - mae: 70.5862 - val_loss: 5331.9746 - val_mae: 68.5180 - learning_rate: 0.0010
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - loss: 5618.6636 - mae: 70.0876 - val_loss: 5261.3179 - val_mae: 68.0065 - learning_rate: 0.0010
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - loss: 5529.9204 - mae: 69.4618 - val_loss: 5191.6729 - val_mae: 67.4988 - learning_rate: 0.0010
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - loss: 5465.7729 - mae: 68.9649 - val_loss: 5122.8276 - val_mae: 66.9938 - learning_rate: 0.0010
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - loss: 5387.8730 - mae: 68.4529 - val_loss: 5054.9683 - val_mae: 66.4924 - learning_rate: 0.0010
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - loss: 5320.9668 - mae: 67.9600 - val_loss: 4988.1021 - val_mae: 65.9949 - learning_rate: 0.0010
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 387ms/step - loss: 5270.0981 - mae: 67.6065 - val_loss: 4922.1675 - val_mae: 65.5010 - learning_rate: 0.0010
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 643ms/step - loss: 5224.0547 - mae: 67.2629 - val_loss: 4857.2427 - val_mae: 65.0112 - learning_rate: 0.0010
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 400ms/step - loss: 5142.1045 - mae: 66.6461 - val_loss: 4793.1494 - val_mae: 64.5245 - learning_rate: 0.0010
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 403ms/step - loss: 5092.3389 - mae: 66.2804 - val_loss: 4729.9653 - val_mae: 64.0415 - learning_rate: 0.0010
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 618ms/step - loss: 5022.4678 - mae: 65.7412 - val_loss: 4667.6426 - val_mae: 63.5618 - learning_rate: 0.0010
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - loss: 4953.0146 - mae: 65.2319 - val_loss: 4605.9717 - val_mae: 63.0840 - learning_rate: 0.0010
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 395ms/step - loss: 4882.2051 - mae: 64.6980 - val_loss: 4545.0542 - val_mae: 62.6089 - learning_rate: 0.0010
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 628ms/step - loss: 4814.4116 - mae: 64.1940 - val_loss: 4484.9609 - val_mae: 62.1371 - learning_rate: 0.0010
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 4761.1138 - mae: 63.7922 - val_loss: 4425.6353 - val_mae: 61.6681 - learning_rate: 0.0010
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - loss: 4698.2012 - mae: 63.2760 - val_loss: 4367.1577 - val_mae: 61.2026 - learning_rate: 0.0010
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 400ms/step - loss: 4632.2471 - mae: 62.7870 - val_loss: 4309.3315 - val_mae: 60.7393 - learning_rate: 0.0010
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 571ms/step - loss: 4596.3652 - mae: 62.4804 - val_loss: 4252.2593 - val_mae: 60.2790 - learning_rate: 0.0010
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 421ms/step - loss: 4516.7485 - mae: 61.8741 - val_loss: 4195.8911 - val_mae: 59.8212 - learning_rate: 0.0010
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - loss: 4475.7988 - mae: 61.5261 - val_loss: 4140.1978 - val_mae: 59.3659 - learning_rate: 0.0010
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 484ms/step - loss: 4420.2769 - mae: 61.1232 - val_loss: 4085.2593 - val_mae: 58.9136 - learning_rate: 0.0010
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 378ms/step - loss: 4330.6821 - mae: 60.3880 - val_loss: 4030.9353 - val_mae: 58.4635 - learning_rate: 0.0010
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - loss: 4294.8818 - mae: 60.1180 - val_loss: 3977.2854 - val_mae: 58.0161 - learning_rate: 0.0010
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 479ms/step - loss: 4250.8359 - mae: 59.7506 - val_loss: 3924.3616 - val_mae: 57.5717 - learning_rate: 0.0010
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 509ms/step - loss: 4204.9316 - mae: 59.3998 - val_loss: 3872.0889 - val_mae: 57.1296 - learning_rate: 0.0010
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - loss: 4153.7461 - mae: 58.9508 - val_loss: 3820.4895 - val_mae: 56.6903 - learning_rate: 0.0010
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 381ms/step - loss: 4090.2393 - mae: 58.4244 - val_loss: 3769.4944 - val_mae: 56.2533 - learning_rate: 0.0010
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 445ms/step - loss: 4036.1621 - mae: 57.9625 - val_loss: 3719.0803 - val_mae: 55.8185 - learning_rate: 0.0010
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - loss: 3958.5725 - mae: 57.3707 - val_loss: 3669.2109 - val_mae: 55.3856 - learning_rate: 0.0010
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - loss: 3895.3938 - mae: 56.7565 - val_loss: 3619.9531 - val_mae: 54.9553 - learning_rate: 0.0010
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 592ms/step - loss: 3842.8630 - mae: 56.3441 - val_loss: 3571.2742 - val_mae: 54.5273 - learning_rate: 0.0010
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 412ms/step - loss: 3824.0901 - mae: 56.1843 - val_loss: 3523.1555 - val_mae: 54.1014 - learning_rate: 0.0010
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 384ms/step - loss: 3767.5869 - mae: 55.6821 - val_loss: 3475.6030 - val_mae: 53.6780 - learning_rate: 0.0010
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 580ms/step - loss: 3754.2739 - mae: 55.5784 - val_loss: 3428.6853 - val_mae: 53.2572 - learning_rate: 0.0010
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - loss: 3675.5098 - mae: 54.9030 - val_loss: 3382.3740 - val_mae: 52.8388 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step
# Fold 3 — Test MAE SBP: 81.132, DBP: 30.280
#
# ========================================
# Cross-fold MAE summary
# SBP MAE mean: 78.019 (std: 3.089)
# DBP MAE mean: 32.879 (std: 3.284)

# %%
# 셀 6: 학습곡선(MAE) 플롯
plt.figure(figsize=(12, 6))

for fi, hist in enumerate(hist_list):
    # train MAE
    plt.plot(hist.history['mae'], label=f'Fold {fi} Train MAE', linestyle='-')
    # val MAE
    plt.plot(hist.history['val_mae'], label=f'Fold {fi} Val MAE', linestyle='--')

plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('CNN-LSTM Fold별 학습곡선 (MAE)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44257 (\N{HANGUL SYLLABLE GOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 셀 7: SBP/DBP MAE 별도 플롯
plt.figure(figsize=(14, 6))

# SBP
plt.subplot(1, 2, 1)
for fi, hist in enumerate(hist_list):
    plt.plot(hist.history['mae'][:,0] if 'mae' in hist.history and isinstance(hist.history['mae'][0], (list, np.ndarray)) else hist.history['mae'],
             label=f'Fold {fi} Train MAE')
    plt.plot(hist.history['val_mae'][:,0] if 'val_mae' in hist.history and isinstance(hist.history['val_mae'][0], (list, np.ndarray)) else hist.history['val_mae'],
             label=f'Fold {fi} Val MAE', linestyle='--')
plt.title('SBP MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.grid(True, alpha=0.3)
plt.legend(fontsize=8)

# DBP
plt.subplot(1, 2, 2)
for fi, hist in enumerate(hist_list):
    plt.plot(hist.history['mae'][:,1] if 'mae' in hist.history and isinstance(hist.history['mae'][0], (list, np.ndarray)) else hist.history['mae'],
             label=f'Fold {fi} Train MAE')
    plt.plot(hist.history['val_mae'][:,1] if 'val_mae' in hist.history and isinstance(hist.history['val_mae'][0], (list, np.ndarray)) else hist.history['val_mae'],
             label=f'Fold {fi} Val MAE', linestyle='--')
plt.title('DBP MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.grid(True, alpha=0.3)
plt.legend(fontsize=8)

plt.tight_layout()
plt.show()
